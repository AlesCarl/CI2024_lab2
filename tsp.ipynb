# %% [markdown]
# Copyright **`(c)`** 2024 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
import logging
from itertools import combinations
import pandas as pd
from tqdm.auto import tqdm

import random

import numpy as np
from geopy.distance import geodesic
import networkx as nx

from icecream import ic

logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# ## Lab2 - TSP
#
# https://www.wolframcloud.com/obj/giovanni.squillero/Published/Lab2-tsp.nb

# %%
# Calculate the distance matrix

CITIES = pd.read_csv('../cities/russia.csv', header=None, names=['name', 'lat', 'lon'])
DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))

for c1, c2 in combinations(CITIES.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km
CITIES.head()


# US : 3_901_662_065_726,7 km shortees tour 
# italy : 4_172.76km shortest tour
# russia : 32_722.5km km shortest tour
# Out:
#           name    lat     lon
# 0       Abakan  53.72   91.43
# 1      Achinsk  56.28   90.50
# 2   Almetyevsk  54.90   52.31
# 3      Angarsk  52.57  103.91
# 4  Arkhangelsk  64.57   40.53

# %%
def tsp_cost(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost

# %% [markdown]
# # First  Algorithm

# %%
best_tsp = None
best_cost = float('inf')

for i in range(len(CITIES)):


    visited = np.full(len(CITIES), False)
    dist = DIST_MATRIX.copy()
    city = i
    visited[city] = True
    tsp = [int(city)]

    while not np.all(visited):

        dist[:, city] = np.inf
        closest = np.argmin(dist[city])

        visited[closest] = True
        city = closest
        tsp.append(int(city))
    
    tsp.append(tsp[0])  # Chiudo  percorso
    cost = tsp_cost(tsp)

    
    if cost < best_cost:
        best_cost = cost
        best_tsp = tsp

# Output finale del miglior percorso
logging.info(f"Best path found has length {best_cost:.2f} km") 

for c1, c2 in zip(best_tsp, best_tsp[1:]):
    logging.info(
        f"step: {CITIES.at[c1,'name']} -> {CITIES.at[c2,'name']} ({DIST_MATRIX[c1,c2]:.2f}km)"
    )
# Out:
# INFO:root:Best path found has length 40051.59 km
# INFO:root:step: Magadan -> Petropavlovsk‐Kamchatskiy (875.16km)
# INFO:root:step: Petropavlovsk‐Kamchatskiy -> Yuzhno‐Sakhalinsk (1321.54km)
# INFO:root:step: Yuzhno‐Sakhalinsk -> Komsomolsk‐na‐Amure (582.17km)
# INFO:root:step: Komsomolsk‐na‐Amure -> Khabarovsk (274.21km)
# INFO:root:step: Khabarovsk -> Ussuriysk (566.90km)
# INFO:root:step: Ussuriysk -> Artyom (50.78km)
# INFO:root:step: Artyom -> Vladivostok (34.21km)
# INFO:root:step: Vladivostok -> Nakhodka (87.36km)
# INFO:root:step: Nakhodka -> Blagoveshchensk (922.98km)
# INFO:root:step: Blagoveshchensk -> Chita (1002.31km)
# INFO:root:step: Chita -> Ulan‐Ude (402.25km)
# INFO:root:step: Ulan‐Ude -> Irkutsk (238.28km)
# INFO:root:step: Irkutsk -> Angarsk (34.88km)
# INFO:root:step: Angarsk -> Bratsk (439.00km)
# INFO:root:step: Bratsk -> Krasnoyarsk (538.01km)
# INFO:root:step: Krasnoyarsk -> Achinsk (161.71km)
# INFO:root:step: Achinsk -> Abakan (291.13km)
# INFO:root:step: Abakan -> Novokuznetsk (285.72km)
# INFO:root:step: Novokuznetsk -> Prokopyevsk (30.63km)
# INFO:root:step: Prokopyevsk -> Leninsk‐Kuznetskiy (91.87km)
# INFO:root:step: Leninsk‐Kuznetskiy -> Kemerovo (74.76km)
# INFO:root:step: Kemerovo -> Tomsk (147.60km)
# INFO:root:step: Tomsk -> Seversk (14.97km)
# INFO:root:step: Seversk -> Novosibirsk (211.49km)
# INFO:root:step: Novosibirsk -> Barnaul (194.50km)
# INFO:root:step: Barnaul -> Biysk (132.82km)
# INFO:root:step: Biysk -> Rubtsovsk (294.26km)
# INFO:root:step: Rubtsovsk -> Omsk (647.47km)
# INFO:root:step: Omsk -> Tobolsk (475.40km)
# INFO:root:step: Tobolsk -> Tyumen (200.98km)
# INFO:root:step: Tyumen -> Kurgan (189.69km)
# INFO:root:step: Kurgan -> Kopeysk (236.87km)
# INFO:root:step: Kopeysk -> Chelyabinsk (14.72km)
# INFO:root:step: Chelyabinsk -> Miass (87.20km)
# INFO:root:step: Miass -> Zlatoust (33.88km)
# INFO:root:step: Zlatoust -> Pervouralsk (194.64km)
# INFO:root:step: Pervouralsk -> Yekaterinburg (40.19km)
# INFO:root:step: Yekaterinburg -> Kamensk‐Uralskiy (95.20km)
# INFO:root:step: Kamensk‐Uralskiy -> Nizhniy Tagil (205.75km)
# INFO:root:step: Nizhniy Tagil -> Perm (220.37km)
# INFO:root:step: Perm -> Berezniki (159.92km)
# INFO:root:step: Berezniki -> Izhevsk (353.17km)
# INFO:root:step: Izhevsk -> Neftekamsk (107.05km)
# INFO:root:step: Neftekamsk -> Naberezhnye Chelny (129.52km)
# INFO:root:step: Naberezhnye Chelny -> Nizhnekamsk (31.95km)
# INFO:root:step: Nizhnekamsk -> Almetyevsk (88.07km)
# INFO:root:step: Almetyevsk -> Oktyabrskiy (88.27km)
# INFO:root:step: Oktyabrskiy -> Ufa (170.17km)
# INFO:root:step: Ufa -> Sterlitamak (128.14km)
# INFO:root:step: Sterlitamak -> Salavat (29.01km)
# INFO:root:step: Salavat -> Orenberg (185.10km)
# INFO:root:step: Orenberg -> Orenburg (0.37km)
# INFO:root:step: Orenburg -> Novotroitsk (232.42km)
# INFO:root:step: Novotroitsk -> Orsk (21.66km)
# INFO:root:step: Orsk -> Magnitogorsk (247.00km)
# INFO:root:step: Magnitogorsk -> Samara (588.03km)
# INFO:root:step: Samara -> Novokuybyshevsk (17.80km)
# INFO:root:step: Novokuybyshevsk -> Tolyatti (49.80km)
# INFO:root:step: Tolyatti -> Syzran (77.41km)
# INFO:root:step: Syzran -> Ulyanovsk (129.19km)
# INFO:root:step: Ulyanovsk -> Dimitrovgrad (75.41km)
# INFO:root:step: Dimitrovgrad -> Kazan (169.13km)
# INFO:root:step: Kazan -> Novocheboksarsk (109.88km)
# INFO:root:step: Novocheboksarsk -> Cheboksary (15.59km)
# INFO:root:step: Cheboksary -> Yoshkar‐Ola (68.49km)
# INFO:root:step: Yoshkar‐Ola -> Nizhny Novgorod (240.88km)
# INFO:root:step: Nizhny Novgorod -> Dzerzhinsk (34.91km)
# INFO:root:step: Dzerzhinsk -> Arzamas (98.38km)
# INFO:root:step: Arzamas -> Murom (114.53km)
# INFO:root:step: Murom -> Kovrov (98.78km)
# INFO:root:step: Kovrov -> Vladimir (62.07km)
# INFO:root:step: Vladimir -> Orekhovo‐Zuevo (95.53km)
# INFO:root:step: Orekhovo‐Zuevo -> Noginsk (34.00km)
# INFO:root:step: Noginsk -> Elektrostal (6.68km)
# INFO:root:step: Elektrostal -> Zheleznodorozhnyy (26.94km)
# INFO:root:step: Zheleznodorozhnyy -> Balashikha (6.96km)
# INFO:root:step: Balashikha -> Shchyolkovo (11.97km)
# INFO:root:step: Shchyolkovo -> Korolyov (12.70km)
# INFO:root:step: Korolyov -> Mytishchi (5.74km)
# INFO:root:step: Mytishchi -> Khimki (18.28km)
# INFO:root:step: Khimki -> Zelenograd (10.91km)
# INFO:root:step: Zelenograd -> Moscow (29.58km)
# INFO:root:step: Moscow -> Lyubertsy (19.17km)
# INFO:root:step: Lyubertsy -> Zhukovskiy (26.33km)
# INFO:root:step: Zhukovskiy -> Podolsk (47.16km)
# INFO:root:step: Podolsk -> Odintsovo (32.00km)
# INFO:root:step: Odintsovo -> Obninsk (76.71km)
# INFO:root:step: Obninsk -> Serpukhov (54.96km)
# INFO:root:step: Serpukhov -> Tula (81.18km)
# INFO:root:step: Tula -> Novomoskovsk (41.70km)
# INFO:root:step: Novomoskovsk -> Ryazan (115.09km)
# INFO:root:step: Ryazan -> Kolomna (80.15km)
# INFO:root:step: Kolomna -> Sergiyev Posad (143.98km)
# INFO:root:step: Sergiyev Posad -> Tver (150.18km)
# INFO:root:step: Tver -> Rybinsk (220.67km)
# INFO:root:step: Rybinsk -> Yaroslavl (78.17km)
# INFO:root:step: Yaroslavl -> Kostroma (65.38km)
# INFO:root:step: Kostroma -> Ivanovo (84.72km)
# INFO:root:step: Ivanovo -> Vologda (254.39km)
# INFO:root:step: Vologda -> Cherepovets (114.80km)
# INFO:root:step: Cherepovets -> Petrozavodsk (358.19km)
# INFO:root:step: Petrozavodsk -> Saint Petersburg (302.88km)
# INFO:root:step: Saint Petersburg -> Kolpino (25.47km)
# INFO:root:step: Kolpino -> Velikiy Novgorod (142.44km)
# INFO:root:step: Velikiy Novgorod -> Pskov (189.82km)
# INFO:root:step: Pskov -> Velikie Luki (212.88km)
# INFO:root:step: Velikie Luki -> Smolensk (198.09km)
# INFO:root:step: Smolensk -> Bryansk (230.10km)
# INFO:root:step: Bryansk -> Oryol (115.74km)
# INFO:root:step: Oryol -> Kursk (138.18km)
# INFO:root:step: Kursk -> Staryy Oskol (124.13km)
# INFO:root:step: Staryy Oskol -> Voronezh (109.10km)
# INFO:root:step: Voronezh -> Lipetsk (103.13km)
# INFO:root:step: Lipetsk -> Yelets (75.22km)
# INFO:root:step: Yelets -> Tambov (198.07km)
# INFO:root:step: Tambov -> Penza (245.48km)
# INFO:root:step: Penza -> Saransk (109.72km)
# INFO:root:step: Saransk -> Balakovo (295.88km)
# INFO:root:step: Balakovo -> Engels (128.88km)
# INFO:root:step: Engels -> Saratov (9.98km)
# INFO:root:step: Saratov -> Kamyshin (169.44km)
# INFO:root:step: Kamyshin -> Volzhskiy (152.69km)
# INFO:root:step: Volzhskiy -> Volgograd (23.11km)
# INFO:root:step: Volgograd -> Volgodonsk (218.86km)
# INFO:root:step: Volgodonsk -> Shakhty (147.54km)
# INFO:root:step: Shakhty -> Novoshakhtinsk (20.74km)
# INFO:root:step: Novoshakhtinsk -> Novocherkassk (38.39km)
# INFO:root:step: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# INFO:root:step: Rostov‐na‐Donu -> Bataysk (11.52km)
# INFO:root:step: Bataysk -> Taganrog (64.29km)
# INFO:root:step: Taganrog -> Krasnodar (243.49km)
# INFO:root:step: Krasnodar -> Maykop (100.83km)
# INFO:root:step: Maykop -> Armavir (90.38km)
# INFO:root:step: Armavir -> Stavropol (67.23km)
# INFO:root:step: Stavropol -> Nevinnomyssk (45.59km)
# INFO:root:step: Nevinnomyssk -> Cherkessk (38.78km)
# INFO:root:step: Cherkessk -> Kislovodsk (67.64km)
# INFO:root:step: Kislovodsk -> Pyatigorsk (31.40km)
# INFO:root:step: Pyatigorsk -> Nalchik (75.94km)
# INFO:root:step: Nalchik -> Vladikavkaz (100.08km)
# INFO:root:step: Vladikavkaz -> Nazran (21.26km)
# INFO:root:step: Nazran -> Groznyy (73.92km)
# INFO:root:step: Groznyy -> Khasavyurt (72.55km)
# INFO:root:step: Khasavyurt -> Makhachkala (79.91km)
# INFO:root:step: Makhachkala -> Kaspiysk (15.94km)
# INFO:root:step: Kaspiysk -> Derbent (105.61km)
# INFO:root:step: Derbent -> Astrakhan (477.07km)
# INFO:root:step: Astrakhan -> Elista (295.65km)
# INFO:root:step: Elista -> Sochi (464.97km)
# INFO:root:step: Sochi -> Novorossiysk (200.16km)
# INFO:root:step: Novorossiysk -> Belgorod (660.82km)
# INFO:root:step: Belgorod -> Kaluga (437.86km)
# INFO:root:step: Kaluga -> Kirov (936.75km)
# INFO:root:step: Kirov -> Syktyvkar (347.95km)
# INFO:root:step: Syktyvkar -> Arkhangelsk (610.18km)
# INFO:root:step: Arkhangelsk -> Severodvinsk (33.55km)
# INFO:root:step: Severodvinsk -> Murmansk (572.02km)
# INFO:root:step: Murmansk -> Kaliningrad (1712.77km)
# INFO:root:step: Kaliningrad -> Nefteyugansk (3086.69km)
# INFO:root:step: Nefteyugansk -> Surgut (43.14km)
# INFO:root:step: Surgut -> Nizhnevartovsk (173.64km)
# INFO:root:step: Nizhnevartovsk -> Noyabrsk (254.53km)
# INFO:root:step: Noyabrsk -> Novyy Urengoy (328.30km)
# INFO:root:step: Novyy Urengoy -> Norilsk (612.52km)
# INFO:root:step: Norilsk -> Kyzyl (1990.79km)
# INFO:root:step: Kyzyl -> Yakutsk (2400.92km)
# INFO:root:step: Yakutsk -> Magadan (1173.79km)

# %% [markdown]
# # Second Algorithm

# %%
def fitness(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost



#  mutazione 
def insert_mutation(path):
    path = path.copy()
    i, j = random.sample(range(1, len(path) - 1), 2 )   # Evita i punti iniziale e finale

    # Se `j` è maggiore di `i`, l'elemento alla posizione `j` viene inserito dopo `i`
    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    # Se `i` è maggiore di `j`, l'elemento `j` viene inserito prima di `i`
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path



def insert_mutation_temp1(path, temperature):
    path = path.copy()
    
    i = random.randint(1, len(path) ) # non ho messo -2 
    
    # Calcola una distanza massima tra `i` e `j` basata sulla temperatura
    max_distance = int((temperature / 1000) * (len(path) - 2)) 
    max_distance = max(1, min(max_distance, len(path) - 2))  # Limita max_distance all'intervallo valido


    # Scegli `j` con una distanza casuale fino a `max_distance` da `i`
    if random.random() < 0.5:
        # Scegli `j` a sinistra di `i`
        j = max(1, i - random.randint(1, max_distance))
    else:
        # Scegli `j` a destra di `i`
        j = min(len(path) - 2, i + random.randint(1, max_distance))

    # Esegui la mutazione: sposta l'elemento in `j` accanto a `i`
    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path




def insert_mutation_temp2(path, temperature):
    path = path.copy()
    
    # Scegli un indice casuale `i`, evitando il primo e l'ultimo per mantenere il percorso chiuso
    i = random.randint(1, len(path) - 2)
    
    # Calcola una distanza massima tra `i` e `j` basata sulla temperatura
    max_distance = int((temperature / 1000) * (len(path) - 2))
    max_distance = max(1, min(max_distance, len(path) - 2))  # Limita max_distance all'intervallo valido

    # Scegli `j` con una distanza casuale fino a `max_distance` da `i`
    if random.random() < 0.5:
        # Scegli `j` a sinistra di `i`
        j = max(1, i - random.randint(1, max_distance))
    else:
        # Scegli `j` a destra di `i`
        j = min(len(path) - 2, i + random.randint(1, max_distance))

    # Esegui la mutazione: sposta l'elemento in `j` accanto a `i`
    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path 






######
def scrambling_mutation(path):
    path = path.copy()
    # subset da mischiare
    i, j = sorted(random.sample(range(1, len(path) - 1), 2))  # Evita punti iniziale e finale

    subset = path[i:j+1]
    random.shuffle(subset)

    path[i:j+1] = subset

    return path



# recombination non sos
# inver / over   -> it's nice

# %%
## Simulated Annealing 

initial_temp = 1000  
cooling_rate = 0.995
num_iterations = 500_000  # iterazioni

# italy and RUSSIA  only :
buffer_size = 4  # russia - italy  
#buffer_size = int(0.02 * len(CITIES))    # ( US - CHINA ) # 2% del numero totale di città 


current_path = list(range(len(CITIES))) + [0]    # Percorso iniziale che parte e torna alla città 0   *** DA SISTEMARE  . inizia con un percorso meglio?????? 


best_path = current_path
current_cost = fitness(current_path)
best_cost = current_cost

temperature = initial_temp
cost_buffer = []

for iteration in tqdm (range(num_iterations) ): 
        


    #new_path = scrambling_mutation(current_path)  ## 
    new_path = insert_mutation(current_path)  ## 
    #new_path = insert_mutation_temp2(current_path, temperature)  ##

    new_cost = fitness(new_path)

    # Calcola la differenza di costo
    delta_cost = new_cost - current_cost

    # Decide se accettare il nuovo percorso
    if delta_cost < 0 or np.random.random() < np.exp(-delta_cost / temperature):
        current_path = new_path
        current_cost = new_cost

        if current_cost < best_cost:
            best_cost = current_cost
            best_path = current_path

    
    cost_buffer.append(current_cost)
    if len(cost_buffer) > buffer_size:
        cost_buffer.pop(0)

  # Aggiorna la temperatura solo se il trend è in discesa
    if iteration % buffer_size == 0 and len(cost_buffer) == buffer_size:
        avg_cost = np.mean(cost_buffer)
        if avg_cost < current_cost: # Se la media è in discesa ... 
            temperature *= cooling_rate


    if iteration % 10000 == 0:
        logging.info(f"Iteration {iteration}, Best Cost: {best_cost:.2f} km, Temperature: {temperature:.2f}")

    if temperature < 1e-5:
        break

logging.info(f"Best path found with length {best_cost:.2f} km,  after {iteration} iterations")
# Out:
#   0%|          | 0/500000 [00:00<?, ?it/s]
# INFO:root:Iteration 0, Best Cost: 335828.72 km, Temperature: 1000.00
# INFO:root:Iteration 10000, Best Cost: 78401.17 km, Temperature: 114.70
# INFO:root:Iteration 20000, Best Cost: 54293.02 km, Temperature: 58.89
# INFO:root:Iteration 30000, Best Cost: 50278.66 km, Temperature: 39.24
# INFO:root:Iteration 40000, Best Cost: 45701.47 km, Temperature: 30.39
# INFO:root:Iteration 50000, Best Cost: 43092.24 km, Temperature: 26.14
# INFO:root:Iteration 60000, Best Cost: 42270.88 km, Temperature: 22.72
# INFO:root:Iteration 70000, Best Cost: 40320.48 km, Temperature: 20.55
# INFO:root:Iteration 80000, Best Cost: 39918.66 km, Temperature: 18.50
# INFO:root:Iteration 90000, Best Cost: 39169.59 km, Temperature: 16.65
# INFO:root:Iteration 100000, Best Cost: 38901.93 km, Temperature: 14.91
# INFO:root:Iteration 110000, Best Cost: 38740.35 km, Temperature: 13.83
# INFO:root:Iteration 120000, Best Cost: 38630.05 km, Temperature: 13.09
# INFO:root:Iteration 130000, Best Cost: 38574.41 km, Temperature: 12.45
# INFO:root:Iteration 140000, Best Cost: 38574.41 km, Temperature: 11.78
# INFO:root:Iteration 150000, Best Cost: 38535.32 km, Temperature: 11.21
# INFO:root:Iteration 160000, Best Cost: 38535.32 km, Temperature: 10.50
# INFO:root:Iteration 170000, Best Cost: 38535.32 km, Temperature: 9.89
# INFO:root:Iteration 180000, Best Cost: 38447.63 km, Temperature: 9.55
# INFO:root:Iteration 190000, Best Cost: 38423.06 km, Temperature: 9.08
# INFO:root:Iteration 200000, Best Cost: 38402.70 km, Temperature: 8.94
# INFO:root:Iteration 210000, Best Cost: 38325.34 km, Temperature: 8.46
# INFO:root:Iteration 220000, Best Cost: 38287.70 km, Temperature: 8.13
# INFO:root:Iteration 230000, Best Cost: 38267.59 km, Temperature: 7.70
# INFO:root:Iteration 240000, Best Cost: 37875.18 km, Temperature: 7.54
# INFO:root:Iteration 250000, Best Cost: 37841.58 km, Temperature: 7.47
# INFO:root:Iteration 260000, Best Cost: 37704.74 km, Temperature: 7.25
# INFO:root:Iteration 270000, Best Cost: 37540.22 km, Temperature: 7.14
# INFO:root:Iteration 280000, Best Cost: 37534.27 km, Temperature: 6.96
# INFO:root:Iteration 290000, Best Cost: 37534.27 km, Temperature: 6.79
# INFO:root:Iteration 300000, Best Cost: 37534.27 km, Temperature: 6.59
# INFO:root:Iteration 310000, Best Cost: 37534.27 km, Temperature: 6.46
# INFO:root:Iteration 320000, Best Cost: 37534.27 km, Temperature: 6.23
# INFO:root:Iteration 330000, Best Cost: 37534.27 km, Temperature: 6.11
# INFO:root:Iteration 340000, Best Cost: 37534.27 km, Temperature: 5.99
# INFO:root:Iteration 350000, Best Cost: 37534.27 km, Temperature: 5.81
# INFO:root:Iteration 360000, Best Cost: 37534.06 km, Temperature: 5.61
# INFO:root:Iteration 370000, Best Cost: 37514.42 km, Temperature: 5.56
# INFO:root:Iteration 380000, Best Cost: 37514.42 km, Temperature: 5.45
# INFO:root:Iteration 390000, Best Cost: 37512.04 km, Temperature: 5.31
# INFO:root:Iteration 400000, Best Cost: 37512.04 km, Temperature: 5.23
# INFO:root:Iteration 410000, Best Cost: 37512.04 km, Temperature: 5.15
# INFO:root:Iteration 420000, Best Cost: 37512.04 km, Temperature: 5.08
# INFO:root:Iteration 430000, Best Cost: 37512.04 km, Temperature: 5.08
# INFO:root:Iteration 440000, Best Cost: 37512.04 km, Temperature: 5.00
# INFO:root:Iteration 450000, Best Cost: 37512.04 km, Temperature: 4.88
# INFO:root:Iteration 460000, Best Cost: 37469.18 km, Temperature: 4.80
# INFO:root:Iteration 470000, Best Cost: 37469.18 km, Temperature: 4.66
# INFO:root:Iteration 480000, Best Cost: 37469.18 km, Temperature: 4.52
# INFO:root:Iteration 490000, Best Cost: 37459.83 km, Temperature: 4.50
# INFO:root:Best path found with length 37459.83 km,  after 499999 iterations

# %%
import logging
from itertools import combinations
import pandas as pd
from tqdm.auto import tqdm

import random

import numpy as np
from geopy.distance import geodesic
import networkx as nx

from icecream import ic

logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# ## Lab2 - TSP

# %%
# Calculate the distance matrix

CITIES = pd.read_csv('../cities/china.csv', header=None, names=['name', 'lat', 'lon'])
DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))

for c1, c2 in combinations(CITIES.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km
CITIES.head()


# US : 3_901_662_065_726,7 km shortees tour 
# italy : 4_172.76km shortest tour
# russia : 32_722.5km km shortest tour
# Out:
#      name        lat         lon
# 0  Acheng  45.540000  126.960000
# 1    Aksu  41.150000   80.250000
# 2   Alaer  40.515556   81.263611
# 3   Altay  47.840000   88.130000
# 4    Anbu  23.460000  116.680000

# %%
def tsp_cost(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost

# %% [markdown]
# # GREEDY :

# %%
best_tsp = None
best_cost = float('inf')



for i in range(len(CITIES)):


    visited = np.full(len(CITIES), False)
    dist = DIST_MATRIX.copy()
    city = i
    visited[city] = True
    tsp = [int(city)]

    while not np.all(visited):

        dist[:, city] = np.inf
        closest = np.argmin(dist[city])

        visited[closest] = True
        city = closest
        tsp.append(int(city))
    
    tsp.append(tsp[0])  # Chiudo  percorso
    cost = tsp_cost(tsp)

    
    if cost < best_cost:
        best_cost = cost
        best_tsp = tsp

# Output finale del miglior percorso
logging.info(f"Best path found has length {best_cost:.2f} km" ) 

for c1, c2 in zip(best_tsp, best_tsp[1:]):
    logging.info(
        f"step: {CITIES.at[c1,'name']} -> {CITIES.at[c2,'name']} ({DIST_MATRIX[c1,c2]:.2f}km)"
    )
# Out:
# INFO:root:Best path found has length 62116.04 km
# INFO:root:step: Weihai -> Wendeng (33.59km)
# INFO:root:step: Wendeng -> Rushan (59.18km)
# INFO:root:step: Rushan -> Haiyang (32.50km)
# INFO:root:step: Haiyang -> Laiyang (46.80km)
# INFO:root:step: Laiyang -> Laixi (18.76km)
# INFO:root:step: Laixi -> Pingdu (53.61km)
# INFO:root:step: Pingdu -> Laizhou (42.17km)
# INFO:root:step: Laizhou -> Zhaocheng (46.72km)
# INFO:root:step: Zhaocheng -> Longkou (32.95km)
# INFO:root:step: Longkou -> Penglai (40.08km)
# INFO:root:step: Penglai -> Qixia (58.11km)
# INFO:root:step: Qixia -> Yantai (55.76km)
# INFO:root:step: Yantai -> Jimo (152.63km)
# INFO:root:step: Jimo -> Qingdao (36.63km)
# INFO:root:step: Qingdao -> Jiaozhou (37.74km)
# INFO:root:step: Jiaozhou -> Gaomi (25.04km)
# INFO:root:step: Gaomi -> Anqiu (50.42km)
# INFO:root:step: Anqiu -> Weifang (33.17km)
# INFO:root:step: Weifang -> Changyi (29.12km)
# INFO:root:step: Changyi -> Shouguang (61.09km)
# INFO:root:step: Shouguang -> Qingzhou (29.10km)
# INFO:root:step: Qingzhou -> Yidu (2.04km)
# INFO:root:step: Yidu -> Zibo (39.23km)
# INFO:root:step: Zibo -> Zhoucun (18.83km)
# INFO:root:step: Zhoucun -> Zhangqiu (31.46km)
# INFO:root:step: Zhangqiu -> Boshan (44.53km)
# INFO:root:step: Boshan -> Laiwu (35.44km)
# INFO:root:step: Laiwu -> Xintai (34.49km)
# INFO:root:step: Xintai -> Taian (66.59km)
# INFO:root:step: Taian -> Jinan (53.25km)
# INFO:root:step: Jinan -> Liaocheng (95.99km)
# INFO:root:step: Liaocheng -> Linqing (53.34km)
# INFO:root:step: Linqing -> Nangong (64.34km)
# INFO:root:step: Nangong -> Jizhou (28.10km)
# INFO:root:step: Jizhou -> Hengshui (21.50km)
# INFO:root:step: Hengshui -> Shenzhou (33.22km)
# INFO:root:step: Shenzhou -> Xinji (34.58km)
# INFO:root:step: Xinji -> Gaocheng (33.50km)
# INFO:root:step: Gaocheng -> Luancheng (22.13km)
# INFO:root:step: Luancheng -> Shijiazhuang (24.07km)
# INFO:root:step: Shijiazhuang -> Luquan (14.80km)
# INFO:root:step: Luquan -> Xinle (47.41km)
# INFO:root:step: Xinle -> Dingzhou (27.75km)
# INFO:root:step: Dingzhou -> Anguo (31.16km)
# INFO:root:step: Anguo -> Baoding (52.29km)
# INFO:root:step: Baoding -> Renqiu (54.63km)
# INFO:root:step: Renqiu -> Hejian (27.87km)
# INFO:root:step: Hejian -> Botou (57.71km)
# INFO:root:step: Botou -> Cangzhou (39.44km)
# INFO:root:step: Cangzhou -> Huanghua (42.42km)
# INFO:root:step: Huanghua -> Gangdong (61.10km)
# INFO:root:step: Gangdong -> Tanggu (14.30km)
# INFO:root:step: Tanggu -> Hangu (27.25km)
# INFO:root:step: Hangu -> Tianjin (51.33km)
# INFO:root:step: Tianjin -> Langfang (62.33km)
# INFO:root:step: Langfang -> Huangcun (39.39km)
# INFO:root:step: Huangcun -> Beijing (22.18km)
# INFO:root:step: Beijing -> Tongzhou (20.79km)
# INFO:root:step: Tongzhou -> Yanjiao (15.33km)
# INFO:root:step: Yanjiao -> Sanhe (24.71km)
# INFO:root:step: Sanhe -> Shunyi (39.86km)
# INFO:root:step: Shunyi -> Changping (38.79km)
# INFO:root:step: Changping -> Mentougou (33.01km)
# INFO:root:step: Mentougou -> Fangshan (29.31km)
# INFO:root:step: Fangshan -> Zhuozhou (22.99km)
# INFO:root:step: Zhuozhou -> Gaobeidian (22.81km)
# INFO:root:step: Gaobeidian -> Bazhou (49.83km)
# INFO:root:step: Bazhou -> Tangshan (164.78km)
# INFO:root:step: Tangshan -> Linxi (22.43km)
# INFO:root:step: Linxi -> Zunhua (66.69km)
# INFO:root:step: Zunhua -> Chengde (86.30km)
# INFO:root:step: Chengde -> Lingyuan (126.80km)
# INFO:root:step: Lingyuan -> Chaoyang (94.76km)
# INFO:root:step: Chaoyang -> Beipiao (37.06km)
# INFO:root:step: Beipiao -> Fuxin (77.32km)
# INFO:root:step: Fuxin -> Beining (47.93km)
# INFO:root:step: Beining -> Panjin (51.12km)
# INFO:root:step: Panjin -> Linghai (58.76km)
# INFO:root:step: Linghai -> Jinzhou (21.62km)
# INFO:root:step: Jinzhou -> Huludao (50.11km)
# INFO:root:step: Huludao -> Xingcheng (13.96km)
# INFO:root:step: Xingcheng -> Qinhuangdao (121.57km)
# INFO:root:step: Qinhuangdao -> Wafangdian (206.78km)
# INFO:root:step: Wafangdian -> Pulandian (24.67km)
# INFO:root:step: Pulandian -> Dalian (59.65km)
# INFO:root:step: Dalian -> Zhuanghe (142.37km)
# INFO:root:step: Zhuanghe -> Gaizhou (94.94km)
# INFO:root:step: Gaizhou -> Dashiqiao (29.53km)
# INFO:root:step: Dashiqiao -> Yingkou (18.90km)
# INFO:root:step: Yingkou -> Jiupu (71.86km)
# INFO:root:step: Jiupu -> Anshan (5.55km)
# INFO:root:step: Anshan -> Liaoyang (26.23km)
# INFO:root:step: Liaoyang -> Dengta (21.32km)
# INFO:root:step: Dengta -> Sujiatun (25.18km)
# INFO:root:step: Sujiatun -> Shenyang (18.04km)
# INFO:root:step: Shenyang -> Yuhong (4.71km)
# INFO:root:step: Yuhong -> Dongling (4.99km)
# INFO:root:step: Dongling -> Fushun (27.15km)
# INFO:root:step: Fushun -> Tieling (48.02km)
# INFO:root:step: Tieling -> Tiefa (28.18km)
# INFO:root:step: Tiefa -> Xinmin (77.63km)
# INFO:root:step: Xinmin -> Liaozhong (54.94km)
# INFO:root:step: Liaozhong -> Benxi (87.58km)
# INFO:root:step: Benxi -> Fengcheng (101.30km)
# INFO:root:step: Fengcheng -> Dandong (45.45km)
# INFO:root:step: Dandong -> Donggang (36.20km)
# INFO:root:step: Donggang -> Tonghua (256.15km)
# INFO:root:step: Tonghua -> Baishan (45.88km)
# INFO:root:step: Baishan -> Linjiang (42.84km)
# INFO:root:step: Linjiang -> Huadian (128.51km)
# INFO:root:step: Huadian -> Panshi (56.40km)
# INFO:root:step: Panshi -> Meihekou (55.16km)
# INFO:root:step: Meihekou -> Liaoyuan (60.38km)
# INFO:root:step: Liaoyuan -> Siping (71.76km)
# INFO:root:step: Siping -> Gongzhuling (54.24km)
# INFO:root:step: Gongzhuling -> Changchun (59.12km)
# INFO:root:step: Changchun -> Jiutai (50.12km)
# INFO:root:step: Jiutai -> Dehui (43.68km)
# INFO:root:step: Dehui -> Yushu (75.90km)
# INFO:root:step: Yushu -> Wuchang (47.68km)
# INFO:root:step: Wuchang -> Shulan (59.07km)
# INFO:root:step: Shulan -> Jishu (17.91km)
# INFO:root:step: Jishu -> Jilin city (50.81km)
# INFO:root:step: Jilin city -> Jiaohe (65.64km)
# INFO:root:step: Jiaohe -> Dunhua (82.15km)
# INFO:root:step: Dunhua -> Helong (110.22km)
# INFO:root:step: Helong -> Longjing (42.88km)
# INFO:root:step: Longjing -> Yanji (14.70km)
# INFO:root:step: Yanji -> Tumen (26.45km)
# INFO:root:step: Tumen -> Huichun (46.09km)
# INFO:root:step: Huichun -> Ningan (179.31km)
# INFO:root:step: Ningan -> Hailin (26.54km)
# INFO:root:step: Hailin -> Mudanjiang (18.30km)
# INFO:root:step: Mudanjiang -> Muleng (81.67km)
# INFO:root:step: Muleng -> Hengshan (43.08km)
# INFO:root:step: Hengshan -> Jixi (12.77km)
# INFO:root:step: Jixi -> Didao (8.52km)
# INFO:root:step: Didao -> Qitaihe (52.26km)
# INFO:root:step: Qitaihe -> Mishan (84.93km)
# INFO:root:step: Mishan -> Hulin (85.55km)
# INFO:root:step: Hulin -> Baoshan (148.92km)
# INFO:root:step: Baoshan -> Shuangyashan (11.53km)
# INFO:root:step: Shuangyashan -> Jiamusi (78.45km)
# INFO:root:step: Jiamusi -> Hegang (63.39km)
# INFO:root:step: Hegang -> Nancha (88.49km)
# INFO:root:step: Nancha -> Yichun (72.65km)
# INFO:root:step: Yichun -> Tieli (108.21km)
# INFO:root:step: Tieli -> Suihua (89.11km)
# INFO:root:step: Suihua -> Hailun (91.24km)
# INFO:root:step: Hailun -> Beian (94.46km)
# INFO:root:step: Beian -> Wudalianchi (62.24km)
# INFO:root:step: Wudalianchi -> Nehe (99.17km)
# INFO:root:step: Nehe -> Qiqihar (142.80km)
# INFO:root:step: Qiqihar -> Hulan Ergi (33.36km)
# INFO:root:step: Hulan Ergi -> Longjiang (35.60km)
# INFO:root:step: Longjiang -> Zalantun (81.11km)
# INFO:root:step: Zalantun -> Yakeshi (204.36km)
# INFO:root:step: Yakeshi -> Hailar (74.46km)
# INFO:root:step: Hailar -> Hulunbeir (3.42km)
# INFO:root:step: Hulunbeir -> Zhalainuoer (147.71km)
# INFO:root:step: Zhalainuoer -> Manzhouli (24.90km)
# INFO:root:step: Manzhouli -> Genhe (320.38km)
# INFO:root:step: Genhe -> Jiagedagi (186.53km)
# INFO:root:step: Jiagedagi -> Heihe (239.79km)
# INFO:root:step: Heihe -> Ranghulu (446.36km)
# INFO:root:step: Ranghulu -> Saertu (13.95km)
# INFO:root:step: Saertu -> Longfeng (8.21km)
# INFO:root:step: Longfeng -> Honggang (20.45km)
# INFO:root:step: Honggang -> Anda (35.45km)
# INFO:root:step: Anda -> Zhaodong (62.75km)
# INFO:root:step: Zhaodong -> Harbin (62.99km)
# INFO:root:step: Harbin -> Acheng (33.60km)
# INFO:root:step: Acheng -> Shuangcheng (57.24km)
# INFO:root:step: Shuangcheng -> Zhaoyuan (96.34km)
# INFO:root:step: Zhaoyuan -> Songyuan (44.10km)
# INFO:root:step: Songyuan -> Qianguo (4.81km)
# INFO:root:step: Qianguo -> Qianan (63.65km)
# INFO:root:step: Qianan -> Taonan (104.56km)
# INFO:root:step: Taonan -> Baicheng (32.38km)
# INFO:root:step: Baicheng -> Ulanhot (78.08km)
# INFO:root:step: Ulanhot -> Tongliao (279.51km)
# INFO:root:step: Tongliao -> Shuangliao (100.03km)
# INFO:root:step: Shuangliao -> Chifeng (396.55km)
# INFO:root:step: Chifeng -> Xilinhot (298.76km)
# INFO:root:step: Xilinhot -> Zhangjiakou (359.34km)
# INFO:root:step: Zhangjiakou -> Ulanchabu (152.53km)
# INFO:root:step: Ulanchabu -> Jining (5.75km)
# INFO:root:step: Jining -> Fengzhen (65.65km)
# INFO:root:step: Fengzhen -> Datong (42.93km)
# INFO:root:step: Datong -> Shuozhou (113.95km)
# INFO:root:step: Shuozhou -> Yuanping County (70.83km)
# INFO:root:step: Yuanping County -> Xinzhou (34.39km)
# INFO:root:step: Xinzhou -> Taiyuan (62.77km)
# INFO:root:step: Taiyuan -> Jinzhong (26.27km)
# INFO:root:step: Jinzhong -> Yuci (0.47km)
# INFO:root:step: Yuci -> Gujiao (65.64km)
# INFO:root:step: Gujiao -> Jiexiu (97.44km)
# INFO:root:step: Jiexiu -> Huozhou (53.25km)
# INFO:root:step: Huozhou -> Fenyang (58.32km)
# INFO:root:step: Fenyang -> Lüliang (0.00km)
# INFO:root:step: Lüliang -> Linfen (0.48km)
# INFO:root:step: Linfen -> Houma (58.22km)
# INFO:root:step: Houma -> Yuncheng (70.04km)
# INFO:root:step: Yuncheng -> Sanmenxia (22.51km)
# INFO:root:step: Sanmenxia -> Lingbao (39.08km)
# INFO:root:step: Lingbao -> Yongji (53.80km)
# INFO:root:step: Yongji -> Hancheng (66.96km)
# INFO:root:step: Hancheng -> Tongchuan (130.45km)
# INFO:root:step: Tongchuan -> Weinan (73.53km)
# INFO:root:step: Weinan -> Xian (60.79km)
# INFO:root:step: Xian -> Xianyang (21.49km)
# INFO:root:step: Xianyang -> Xingping (20.80km)
# INFO:root:step: Xingping -> Baoji (102.81km)
# INFO:root:step: Baoji -> Hanzhong (139.44km)
# INFO:root:step: Hanzhong -> Guangyuan (133.55km)
# INFO:root:step: Guangyuan -> Langzhong (94.61km)
# INFO:root:step: Langzhong -> Bazhong (80.98km)
# INFO:root:step: Bazhong -> Daxian (98.59km)
# INFO:root:step: Daxian -> Dazhou (6.21km)
# INFO:root:step: Dazhou -> Wanyuan (95.85km)
# INFO:root:step: Wanyuan -> Ankang (125.71km)
# INFO:root:step: Ankang -> Shangluo (157.62km)
# INFO:root:step: Shangluo -> Shiyan (164.24km)
# INFO:root:step: Shiyan -> Danjiangkou (67.65km)
# INFO:root:step: Danjiangkou -> Laohekou (23.26km)
# INFO:root:step: Laohekou -> Dengzhou (54.01km)
# INFO:root:step: Dengzhou -> Nanyang (52.09km)
# INFO:root:step: Nanyang -> Wugang (98.60km)
# INFO:root:step: Wugang -> Pingdingshan (52.65km)
# INFO:root:step: Pingdingshan -> Yuzhou (49.67km)
# INFO:root:step: Yuzhou -> Xinzheng (8.28km)
# INFO:root:step: Xinzheng -> Xinmi (29.62km)
# INFO:root:step: Xinmi -> Xingyang (32.02km)
# INFO:root:step: Xingyang -> Zhengzhou (29.53km)
# INFO:root:step: Zhengzhou -> Changge (60.11km)
# INFO:root:step: Changge -> Xuchang (22.12km)
# INFO:root:step: Xuchang -> Luohe (53.57km)
# INFO:root:step: Luohe -> Zhoukou (56.22km)
# INFO:root:step: Zhoukou -> Jieshou (79.70km)
# INFO:root:step: Jieshou -> Bozhou (78.60km)
# INFO:root:step: Bozhou -> Yongcheng (64.17km)
# INFO:root:step: Yongcheng -> Huaibei (27.82km)
# INFO:root:step: Huaibei -> Suzhou (43.62km)
# INFO:root:step: Suzhou -> Xuzhou (74.35km)
# INFO:root:step: Xuzhou -> Xiazhen (61.45km)
# INFO:root:step: Xiazhen -> Tengzhou (30.30km)
# INFO:root:step: Tengzhou -> Zoucheng (38.23km)
# INFO:root:step: Zoucheng -> Zouxian (2.66km)
# INFO:root:step: Zouxian -> Yanzhou (18.97km)
# INFO:root:step: Yanzhou -> Qufu (14.68km)
# INFO:root:step: Qufu -> Yucheng (87.63km)
# INFO:root:step: Yucheng -> Shangqiu (92.74km)
# INFO:root:step: Shangqiu -> Heze (89.35km)
# INFO:root:step: Heze -> Xiangcheng (41.54km)
# INFO:root:step: Xiangcheng -> Puyang (37.86km)
# INFO:root:step: Puyang -> Anyang (70.80km)
# INFO:root:step: Anyang -> Hebi (18.59km)
# INFO:root:step: Hebi -> Linzhou (33.37km)
# INFO:root:step: Linzhou -> Linshui (56.73km)
# INFO:root:step: Linshui -> Wuan (27.76km)
# INFO:root:step: Wuan -> Handan (29.15km)
# INFO:root:step: Handan -> Shahe (38.25km)
# INFO:root:step: Shahe -> Xingtai (17.48km)
# INFO:root:step: Xingtai -> Yangquan (120.44km)
# INFO:root:step: Yangquan -> Changzhi (200.33km)
# INFO:root:step: Changzhi -> Gaoping (36.54km)
# INFO:root:step: Gaoping -> Jincheng (34.58km)
# INFO:root:step: Jincheng -> Jiaozuo (45.00km)
# INFO:root:step: Jiaozuo -> Qinyang (32.00km)
# INFO:root:step: Qinyang -> Mengzhou (23.01km)
# INFO:root:step: Mengzhou -> Yanshi (20.34km)
# INFO:root:step: Yanshi -> Xiaoyi (15.79km)
# INFO:root:step: Xiaoyi -> Gongyi (1.57km)
# INFO:root:step: Gongyi -> Dengfeng (34.25km)
# INFO:root:step: Dengfeng -> Ruzhou (38.72km)
# INFO:root:step: Ruzhou -> Jiyuan (105.73km)
# INFO:root:step: Jiyuan -> Yima (76.65km)
# INFO:root:step: Yima -> Huixian (193.98km)
# INFO:root:step: Huixian -> Xinxiang (16.75km)
# INFO:root:step: Xinxiang -> Weihui (20.63km)
# INFO:root:step: Weihui -> Kaifeng (70.25km)
# INFO:root:step: Kaifeng -> Zhumadian (210.37km)
# INFO:root:step: Zhumadian -> Xinyang (93.17km)
# INFO:root:step: Xinyang -> Guangshui (56.94km)
# INFO:root:step: Guangshui -> Anlu (49.90km)
# INFO:root:step: Anlu -> Yingcheng (38.61km)
# INFO:root:step: Yingcheng -> Xiaogan (31.89km)
# INFO:root:step: Xiaogan -> Hanchuan (31.76km)
# INFO:root:step: Hanchuan -> Wuhan (42.71km)
# INFO:root:step: Wuhan -> Ezhou (57.35km)
# INFO:root:step: Ezhou -> Huangzhou (6.25km)
# INFO:root:step: Huangzhou -> Huangshi (34.39km)
# INFO:root:step: Huangshi -> Daye County (17.41km)
# INFO:root:step: Daye County -> Wuxue (61.31km)
# INFO:root:step: Wuxue -> Ruichang (21.77km)
# INFO:root:step: Ruichang -> Jiujiang (31.37km)
# INFO:root:step: Jiujiang -> Hejin (101.97km)
# INFO:root:step: Hejin -> Leping (45.97km)
# INFO:root:step: Leping -> Jingdezhen (33.93km)
# INFO:root:step: Jingdezhen -> Dexing (52.84km)
# INFO:root:step: Dexing -> Shangrao (65.19km)
# INFO:root:step: Shangrao -> Jiangshan (70.53km)
# INFO:root:step: Jiangshan -> Quzhou (35.26km)
# INFO:root:step: Quzhou -> Lanxi (64.69km)
# INFO:root:step: Lanxi -> Jinhua (20.34km)
# INFO:root:step: Jinhua -> Yongkang (44.21km)
# INFO:root:step: Yongkang -> Dongyang (44.47km)
# INFO:root:step: Dongyang -> Yiwu (31.77km)
# INFO:root:step: Yiwu -> Zhuji (23.72km)
# INFO:root:step: Zhuji -> Shaoxing (45.28km)
# INFO:root:step: Shaoxing -> Shangyu (28.68km)
# INFO:root:step: Shangyu -> Yuyao (27.58km)
# INFO:root:step: Yuyao -> Cixi (15.22km)
# INFO:root:step: Cixi -> Ningbo (44.08km)
# INFO:root:step: Ningbo -> Fenghua (28.57km)
# INFO:root:step: Fenghua -> Shengzhou (58.37km)
# INFO:root:step: Shengzhou -> Linhai (88.94km)
# INFO:root:step: Linhai -> Huangyan (25.11km)
# INFO:root:step: Huangyan -> Luqiao (14.89km)
# INFO:root:step: Luqiao -> Jiaojiang (13.03km)
# INFO:root:step: Jiaojiang -> Wenling (35.72km)
# INFO:root:step: Wenling -> Yueqing (47.25km)
# INFO:root:step: Yueqing -> Wenzhou (32.43km)
# INFO:root:step: Wenzhou -> Ruian (19.74km)
# INFO:root:step: Ruian -> Fuding (81.60km)
# INFO:root:step: Fuding -> Fuan (56.69km)
# INFO:root:step: Fuan -> Ningde (49.39km)
# INFO:root:step: Ningde -> Changle (82.94km)
# INFO:root:step: Changle -> Fuqing (28.34km)
# INFO:root:step: Fuqing -> Nantongkuang (27.75km)
# INFO:root:step: Nantongkuang -> Putian (61.08km)
# INFO:root:step: Putian -> Bantou (34.85km)
# INFO:root:step: Bantou -> Quanzhou (53.03km)
# INFO:root:step: Quanzhou -> Jinjiang (8.92km)
# INFO:root:step: Jinjiang -> Qingyang (0.00km)
# INFO:root:step: Qingyang -> Shishi (11.92km)
# INFO:root:step: Shishi -> Nan'an (36.33km)
# INFO:root:step: Nan'an -> Xiamen (64.51km)
# INFO:root:step: Xiamen -> Longhai (32.71km)
# INFO:root:step: Longhai -> Zhangzhou (17.13km)
# INFO:root:step: Zhangzhou -> Zhangping (88.34km)
# INFO:root:step: Zhangping -> Longyan (40.61km)
# INFO:root:step: Longyan -> Yongan (94.28km)
# INFO:root:step: Yongan -> Sanming (36.01km)
# INFO:root:step: Sanming -> Nanping (73.67km)
# INFO:root:step: Nanping -> Jian'ou (47.30km)
# INFO:root:step: Jian'ou -> Jianyang (38.63km)
# INFO:root:step: Jianyang -> Wuyishan (48.94km)
# INFO:root:step: Wuyishan -> Shaowu (73.82km)
# INFO:root:step: Shaowu -> Guixi (112.99km)
# INFO:root:step: Guixi -> Yingtai (17.95km)
# INFO:root:step: Yingtai -> Linchuan (70.96km)
# INFO:root:step: Linchuan -> Fuzhou (2.10km)
# INFO:root:step: Fuzhou -> Zhangshu (80.43km)
# INFO:root:step: Zhangshu -> Gaoan (42.06km)
# INFO:root:step: Gaoan -> Nanchang (57.64km)
# INFO:root:step: Nanchang -> Xinyu (134.92km)
# INFO:root:step: Xinyu -> Jian (74.56km)
# INFO:root:step: Jian -> Jinggangshan (107.38km)
# INFO:root:step: Jinggangshan -> Zixing (99.21km)
# INFO:root:step: Zixing -> Chenzhou (41.42km)
# INFO:root:step: Chenzhou -> Leiyang (71.27km)
# INFO:root:step: Leiyang -> Changning (42.60km)
# INFO:root:step: Changning -> Qidong (59.18km)
# INFO:root:step: Qidong -> Hengyang (51.17km)
# INFO:root:step: Hengyang -> Xiangxiang (94.71km)
# INFO:root:step: Xiangxiang -> Shaoshan (19.25km)
# INFO:root:step: Shaoshan -> Xiangtan (41.89km)
# INFO:root:step: Xiangtan -> Zhuzhou (24.73km)
# INFO:root:step: Zhuzhou -> Liling (37.92km)
# INFO:root:step: Liling -> Xiangdong (24.89km)
# INFO:root:step: Xiangdong -> Pingxiang (11.08km)
# INFO:root:step: Pingxiang -> Liuyang (61.91km)
# INFO:root:step: Liuyang -> Changsha (64.65km)
# INFO:root:step: Changsha -> Miluo (68.24km)
# INFO:root:step: Miluo -> Yueyang (63.40km)
# INFO:root:step: Yueyang -> Linxiang (36.89km)
# INFO:root:step: Linxiang -> Honghu (39.16km)
# INFO:root:step: Honghu -> Chibi (43.13km)
# INFO:root:step: Chibi -> Xianning (35.85km)
# INFO:root:step: Xianning -> Xiantao (92.61km)
# INFO:root:step: Xiantao -> Tianmen (41.69km)
# INFO:root:step: Tianmen -> Qianjiang (36.35km)
# INFO:root:step: Qianjiang -> Shashi (64.60km)
# INFO:root:step: Shashi -> Songzi (1.69km)
# INFO:root:step: Songzi -> Jingzhou (4.61km)
# INFO:root:step: Jingzhou -> Buhe (9.67km)
# INFO:root:step: Buhe -> Zhijiang (49.36km)
# INFO:root:step: Zhijiang -> Zhicheng (28.62km)
# INFO:root:step: Zhicheng -> Yichang (48.71km)
# INFO:root:step: Yichang -> Dangyang (50.39km)
# INFO:root:step: Dangyang -> Jingmen (44.64km)
# INFO:root:step: Jingmen -> Yingzhong (40.32km)
# INFO:root:step: Yingzhong -> Zhongxiang (0.49km)
# INFO:root:step: Zhongxiang -> Yicheng (68.07km)
# INFO:root:step: Yicheng -> Xiangfan (36.20km)
# INFO:root:step: Xiangfan -> Zaoyang (59.80km)
# INFO:root:step: Zaoyang -> Suizhou (74.14km)
# INFO:root:step: Suizhou -> Macheng (169.27km)
# INFO:root:step: Macheng -> Luan (151.60km)
# INFO:root:step: Luan -> Hefei (76.57km)
# INFO:root:step: Hefei -> Feidong (16.48km)
# INFO:root:step: Feidong -> Chaohu (49.94km)
# INFO:root:step: Chaohu -> Wuhu (55.01km)
# INFO:root:step: Wuhu -> Maanshan (43.41km)
# INFO:root:step: Maanshan -> Nanjing (45.44km)
# INFO:root:step: Nanjing -> Jurong (37.28km)
# INFO:root:step: Jurong -> Yizheng (37.63km)
# INFO:root:step: Yizheng -> Zhenjiang (22.37km)
# INFO:root:step: Zhenjiang -> Yangzhou (19.96km)
# INFO:root:step: Yangzhou -> Jiangdu (13.58km)
# INFO:root:step: Jiangdu -> Taizhou (32.68km)
# INFO:root:step: Taizhou -> Jiangyan (22.02km)
# INFO:root:step: Jiangyan -> Taixing (39.94km)
# INFO:root:step: Taixing -> Jingjiang (31.10km)
# INFO:root:step: Jingjiang -> Jiangyin (15.38km)
# INFO:root:step: Jiangyin -> Zhangjiagang (28.05km)
# INFO:root:step: Zhangjiagang -> Nantong (29.79km)
# INFO:root:step: Nantong -> Changshu (41.84km)
# INFO:root:step: Changshu -> Kunshan (36.00km)
# INFO:root:step: Kunshan -> Taicang (15.26km)
# INFO:root:step: Taicang -> Shanghai (43.18km)
# INFO:root:step: Shanghai -> Pinghu (73.00km)
# INFO:root:step: Pinghu -> Jiaxing (26.69km)
# INFO:root:step: Jiaxing -> Tongxiang (25.70km)
# INFO:root:step: Tongxiang -> Haining (18.16km)
# INFO:root:step: Haining -> Wujiang (56.85km)
# INFO:root:step: Wujiang -> Huzhou (53.68km)
# INFO:root:step: Huzhou -> Deqing (35.53km)
# INFO:root:step: Deqing -> Hangzhou (34.36km)
# INFO:root:step: Hangzhou -> Fuyang (30.23km)
# INFO:root:step: Fuyang -> Lin'an (29.63km)
# INFO:root:step: Lin'an -> Ningguo (82.35km)
# INFO:root:step: Ningguo -> Xuanzhou (41.97km)
# INFO:root:step: Xuanzhou -> Yixing (54.41km)
# INFO:root:step: Yixing -> Liyang (47.55km)
# INFO:root:step: Liyang -> Jintan (30.68km)
# INFO:root:step: Jintan -> Yunyang (33.18km)
# INFO:root:step: Yunyang -> Danyang (0.63km)
# INFO:root:step: Danyang -> Changzhou (45.29km)
# INFO:root:step: Changzhou -> Wuxi (38.35km)
# INFO:root:step: Wuxi -> Rugao (92.16km)
# INFO:root:step: Rugao -> Dongtai (56.82km)
# INFO:root:step: Dongtai -> Dafeng (40.67km)
# INFO:root:step: Dafeng -> Yancheng (35.75km)
# INFO:root:step: Yancheng -> Tianchang (48.86km)
# INFO:root:step: Tianchang -> Xinghua (31.62km)
# INFO:root:step: Xinghua -> Gaoyou (42.14km)
# INFO:root:step: Gaoyou -> Huaian (84.51km)
# INFO:root:step: Huaian -> Huaiyin (13.07km)
# INFO:root:step: Huaiyin -> Suqian (79.51km)
# INFO:root:step: Suqian -> Xinyi (48.76km)
# INFO:root:step: Xinyi -> Pizhou (31.88km)
# INFO:root:step: Pizhou -> Zaozhuang (72.01km)
# INFO:root:step: Zaozhuang -> Feicheng (55.44km)
# INFO:root:step: Feicheng -> Linyi (40.53km)
# INFO:root:step: Linyi -> Heilin (52.19km)
# INFO:root:step: Heilin -> Lianyungang (51.61km)
# INFO:root:step: Lianyungang -> Rizhao (95.64km)
# INFO:root:step: Rizhao -> Zhucheng (62.46km)
# INFO:root:step: Zhucheng -> Jiaonan (53.74km)
# INFO:root:step: Jiaonan -> Dongying (221.08km)
# INFO:root:step: Dongying -> Hekou (5.62km)
# INFO:root:step: Hekou -> Binzhou (51.12km)
# INFO:root:step: Binzhou -> Leling (80.30km)
# INFO:root:step: Leling -> Dezhou (86.85km)
# INFO:root:step: Dezhou -> Bengbu (507.97km)
# INFO:root:step: Bengbu -> Huainan (48.31km)
# INFO:root:step: Huainan -> Mingguang (95.04km)
# INFO:root:step: Mingguang -> Chuzhou (60.17km)
# INFO:root:step: Chuzhou -> Lujiang (152.75km)
# INFO:root:step: Lujiang -> Tongcheng (46.95km)
# INFO:root:step: Tongcheng -> Anqing (50.06km)
# INFO:root:step: Anqing -> Chizhou (44.47km)
# INFO:root:step: Chizhou -> Tongling (43.94km)
# INFO:root:step: Tongling -> Huangshan (145.58km)
# INFO:root:step: Huangshan -> Jiande (103.56km)
# INFO:root:step: Jiande -> Lishui (127.05km)
# INFO:root:step: Lishui -> Zhoushan (280.09km)
# INFO:root:step: Zhoushan -> Ruijin (766.94km)
# INFO:root:step: Ruijin -> Ganzhou (108.52km)
# INFO:root:step: Ganzhou -> Nankang (36.02km)
# INFO:root:step: Nankang -> Nanxiong (76.34km)
# INFO:root:step: Nanxiong -> Shaoguan (80.73km)
# INFO:root:step: Shaoguan -> Maba (13.29km)
# INFO:root:step: Maba -> Lecheng (56.00km)
# INFO:root:step: Lecheng -> Lianzhou (106.01km)
# INFO:root:step: Lianzhou -> Hezhou (93.17km)
# INFO:root:step: Hezhou -> Wuzhou (106.27km)
# INFO:root:step: Wuzhou -> Cenxi (68.29km)
# INFO:root:step: Cenxi -> Luoding (59.07km)
# INFO:root:step: Luoding -> Yunfu (51.30km)
# INFO:root:step: Yunfu -> Gaoyao (44.09km)
# INFO:root:step: Gaoyao -> Zhaoqing (2.13km)
# INFO:root:step: Zhaoqing -> Sihui (40.92km)
# INFO:root:step: Sihui -> Xinan (29.06km)
# INFO:root:step: Xinan -> Foshan (28.21km)
# INFO:root:step: Foshan -> Guangzhou (16.64km)
# INFO:root:step: Guangzhou -> Huangpu (17.55km)
# INFO:root:step: Huangpu -> Shiqiao (18.76km)
# INFO:root:step: Shiqiao -> Daliang (15.81km)
# INFO:root:step: Daliang -> Xiaolan (7.32km)
# INFO:root:step: Xiaolan -> Zhongshan (28.60km)
# INFO:root:step: Zhongshan -> Jiangmen (28.32km)
# INFO:root:step: Jiangmen -> Shaping (24.39km)
# INFO:root:step: Shaping -> Kaiping (52.61km)
# INFO:root:step: Kaiping -> Taicheng (15.01km)
# INFO:root:step: Taicheng -> Taishan (1.76km)
# INFO:root:step: Taishan -> Enping (50.38km)
# INFO:root:step: Enping -> Yangjiang (50.23km)
# INFO:root:step: Yangjiang -> Yangchun (40.42km)
# INFO:root:step: Yangchun -> Maoming (99.24km)
# INFO:root:step: Maoming -> Gaozhou (3.29km)
# INFO:root:step: Gaozhou -> Huazhou (38.46km)
# INFO:root:step: Huazhou -> Wuchuan (25.92km)
# INFO:root:step: Wuchuan -> Zhanjiang (47.32km)
# INFO:root:step: Zhanjiang -> Dongli (39.87km)
# INFO:root:step: Dongli -> Leizhou (29.35km)
# INFO:root:step: Leizhou -> Lianjiang (93.64km)
# INFO:root:step: Lianjiang -> Beiliu (87.90km)
# INFO:root:step: Beiliu -> Guiping (106.54km)
# INFO:root:step: Guiping -> Guigang (57.96km)
# INFO:root:step: Guigang -> Laibin (75.34km)
# INFO:root:step: Laibin -> Heshan (40.94km)
# INFO:root:step: Heshan -> Liuzhou (63.57km)
# INFO:root:step: Liuzhou -> Yizhou (70.68km)
# INFO:root:step: Yizhou -> Hechi (56.39km)
# INFO:root:step: Hechi -> Jinchengjiang (25.82km)
# INFO:root:step: Jinchengjiang -> Baise (151.73km)
# INFO:root:step: Baise -> Chongzuo (181.34km)
# INFO:root:step: Chongzuo -> Nanning (107.71km)
# INFO:root:step: Nanning -> Qinzhou (101.17km)
# INFO:root:step: Qinzhou -> Fangchenggang (50.96km)
# INFO:root:step: Fangchenggang -> Dongxing (34.49km)
# INFO:root:step: Dongxing -> Beihai (117.15km)
# INFO:root:step: Beihai -> Lingao (184.02km)
# INFO:root:step: Lingao -> Danzhou (46.50km)
# INFO:root:step: Danzhou -> Wuzhishan (80.72km)
# INFO:root:step: Wuzhishan -> Sanya (60.28km)
# INFO:root:step: Sanya -> Wanning (114.95km)
# INFO:root:step: Wanning -> Qionghai (49.66km)
# INFO:root:step: Qionghai -> Wenchang (50.91km)
# INFO:root:step: Wenchang -> Qiongshan (57.43km)
# INFO:root:step: Qiongshan -> Dongfang (204.33km)
# INFO:root:step: Dongfang -> Zhuhai (621.75km)
# INFO:root:step: Zhuhai -> Shenzhen (62.22km)
# INFO:root:step: Shenzhen -> Danshui (46.21km)
# INFO:root:step: Danshui -> Pingshan (30.86km)
# INFO:root:step: Pingshan -> Huizhou (30.38km)
# INFO:root:step: Huizhou -> Luoyang (15.82km)
# INFO:root:step: Luoyang -> Shilong (46.56km)
# INFO:root:step: Shilong -> Dongguan (12.21km)
# INFO:root:step: Dongguan -> Humen (22.23km)
# INFO:root:step: Humen -> Zengcheng (50.44km)
# INFO:root:step: Zengcheng -> Conghua (43.29km)
# INFO:root:step: Conghua -> Yingde (62.70km)
# INFO:root:step: Yingde -> Qingyuan (63.86km)
# INFO:root:step: Qingyuan -> Heyuan (169.61km)
# INFO:root:step: Heyuan -> Haicheng (106.46km)
# INFO:root:step: Haicheng -> Shanwei (22.24km)
# INFO:root:step: Shanwei -> Jieshi (48.46km)
# INFO:root:step: Jieshi -> Jiazi (24.52km)
# INFO:root:step: Jiazi -> Huicheng (29.50km)
# INFO:root:step: Huicheng -> Lufeng (15.62km)
# INFO:root:step: Lufeng -> Puning (15.32km)
# INFO:root:step: Puning -> Jieyang (34.16km)
# INFO:root:step: Jieyang -> Mianchang (18.68km)
# INFO:root:step: Mianchang -> Haimen (6.95km)
# INFO:root:step: Haimen -> Shantou (19.80km)
# INFO:root:step: Shantou -> Anbu (10.02km)
# INFO:root:step: Anbu -> Chenghai (9.26km)
# INFO:root:step: Chenghai -> Chaozhou (25.82km)
# INFO:root:step: Chaozhou -> Huanggang (36.74km)
# INFO:root:step: Huanggang -> Meizhou (114.89km)
# INFO:root:step: Meizhou -> Xingning (49.38km)
# INFO:root:step: Xingning -> Hepo (82.33km)
# INFO:root:step: Hepo -> Yongzhou (527.51km)
# INFO:root:step: Yongzhou -> Shaoyang (94.16km)
# INFO:root:step: Shaoyang -> Lengshuijiang (78.43km)
# INFO:root:step: Lengshuijiang -> Lianyuan (23.78km)
# INFO:root:step: Lianyuan -> Loudi (33.10km)
# INFO:root:step: Loudi -> Yiyang (100.27km)
# INFO:root:step: Yiyang -> Yuanjiang (25.96km)
# INFO:root:step: Yuanjiang -> Changde (71.76km)
# INFO:root:step: Changde -> Jinshi (68.52km)
# INFO:root:step: Jinshi -> Shishou (54.38km)
# INFO:root:step: Shishou -> Rongcheng (47.48km)
# INFO:root:step: Rongcheng -> Zhangjiajie (244.59km)
# INFO:root:step: Zhangjiajie -> Jishou (116.99km)
# INFO:root:step: Jishou -> Huaihua (86.96km)
# INFO:root:step: Huaihua -> Hongjiang (49.01km)
# INFO:root:step: Hongjiang -> Tongren (105.28km)
# INFO:root:step: Tongren -> Kaili (171.01km)
# INFO:root:step: Kaili -> Fuquan (44.96km)
# INFO:root:step: Fuquan -> Duyun (45.94km)
# INFO:root:step: Duyun -> Guiyang (86.88km)
# INFO:root:step: Guiyang -> Qingzhen (25.46km)
# INFO:root:step: Qingzhen -> Anshun (63.02km)
# INFO:root:step: Anshun -> Liupanshui (112.83km)
# INFO:root:step: Liupanshui -> Xuanwei (84.81km)
# INFO:root:step: Xuanwei -> Qujing (88.80km)
# INFO:root:step: Qujing -> Jinma (113.70km)
# INFO:root:step: Jinma -> Kunming (5.17km)
# INFO:root:step: Kunming -> Majie (5.05km)
# INFO:root:step: Majie -> Anning (22.60km)
# INFO:root:step: Anning -> Haikou (13.15km)
# INFO:root:step: Haikou -> Longquan (48.84km)
# INFO:root:step: Longquan -> Yuxi (53.34km)
# INFO:root:step: Yuxi -> Zhoucheng (2.02km)
# INFO:root:step: Zhoucheng -> Kaiyuan (100.89km)
# INFO:root:step: Kaiyuan -> Gejiu (37.95km)
# INFO:root:step: Gejiu -> Simao (232.06km)
# INFO:root:step: Simao -> Jinghong (89.81km)
# INFO:root:step: Jinghong -> Lincang (223.45km)
# INFO:root:step: Lincang -> Luxi (163.28km)
# INFO:root:step: Luxi -> Ruili (90.10km)
# INFO:root:step: Ruili -> Dali (298.11km)
# INFO:root:step: Dali -> Chuxiong (158.08km)
# INFO:root:step: Chuxiong -> Lucheng (1.18km)
# INFO:root:step: Lucheng -> Panzhihua (172.21km)
# INFO:root:step: Panzhihua -> Xichang (156.59km)
# INFO:root:step: Xichang -> Zhaotong (153.31km)
# INFO:root:step: Zhaotong -> Wufeng (112.57km)
# INFO:root:step: Wufeng -> Bijie (44.91km)
# INFO:root:step: Bijie -> Renhuai (124.73km)
# INFO:root:step: Renhuai -> Zunyi (50.81km)
# INFO:root:step: Zunyi -> Chishui (155.42km)
# INFO:root:step: Chishui -> Luzhou (44.67km)
# INFO:root:step: Luzhou -> Yongchuan (73.96km)
# INFO:root:step: Yongchuan -> Daan (12.22km)
# INFO:root:step: Daan -> Jiangjin (25.77km)
# INFO:root:step: Jiangjin -> Chongqing (44.26km)
# INFO:root:step: Chongqing -> Beibei (31.85km)
# INFO:root:step: Beibei -> Hechuan (22.32km)
# INFO:root:step: Hechuan -> Guang'an (66.31km)
# INFO:root:step: Guang'an -> Huaying (19.30km)
# INFO:root:step: Huaying -> Nanchong (77.66km)
# INFO:root:step: Nanchong -> Suining (63.84km)
# INFO:root:step: Suining -> Ziyang (95.88km)
# INFO:root:step: Ziyang -> Neijiang (73.64km)
# INFO:root:step: Neijiang -> Zigong (32.92km)
# INFO:root:step: Zigong -> Yibin (72.76km)
# INFO:root:step: Yibin -> Leshan (119.92km)
# INFO:root:step: Leshan -> Emeishan (25.23km)
# INFO:root:step: Emeishan -> Yaan (57.23km)
# INFO:root:step: Yaan -> Qionglai (61.07km)
# INFO:root:step: Qionglai -> Chongzhou (30.90km)
# INFO:root:step: Chongzhou -> Dujiangyan (34.18km)
# INFO:root:step: Dujiangyan -> Pengzhou (42.43km)
# INFO:root:step: Pengzhou -> Guanghan (30.26km)
# INFO:root:step: Guanghan -> Deyang (21.12km)
# INFO:root:step: Deyang -> Mianzhu (29.52km)
# INFO:root:step: Mianzhu -> Shifang (0.00km)
# INFO:root:step: Shifang -> Mianyang (56.29km)
# INFO:root:step: Mianyang -> Jiangyou (33.28km)
# INFO:root:step: Jiangyou -> Chengdu (138.55km)
# INFO:root:step: Chengdu -> Meishan (71.85km)
# INFO:root:step: Meishan -> Fuling (341.64km)
# INFO:root:step: Fuling -> Nanchuan (139.30km)
# INFO:root:step: Nanchuan -> Lichuan (87.67km)
# INFO:root:step: Lichuan -> Enshi (52.96km)
# INFO:root:step: Enshi -> Wanxian (118.84km)
# INFO:root:step: Wanxian -> Longnan (435.75km)
# INFO:root:step: Longnan -> Tianshui (151.40km)
# INFO:root:step: Tianshui -> Pingliang (135.97km)
# INFO:root:step: Pingliang -> Guyuan (66.54km)
# INFO:root:step: Guyuan -> Dingxi (154.54km)
# INFO:root:step: Dingxi -> Lanzhou (100.13km)
# INFO:root:step: Lanzhou -> Linxia (64.71km)
# INFO:root:step: Linxia -> Baiyin (135.55km)
# INFO:root:step: Baiyin -> Zhongwei (139.40km)
# INFO:root:step: Zhongwei -> Qingtongxia (82.75km)
# INFO:root:step: Qingtongxia -> Wuzhong (22.37km)
# INFO:root:step: Wuzhong -> Lingwu (16.13km)
# INFO:root:step: Lingwu -> Yinchuan (41.09km)
# INFO:root:step: Yinchuan -> Dawukou (61.15km)
# INFO:root:step: Dawukou -> Shizuishan (41.71km)
# INFO:root:step: Shizuishan -> Hainan (9.84km)
# INFO:root:step: Hainan -> Wuda (24.87km)
# INFO:root:step: Wuda -> Wuhai (16.72km)
# INFO:root:step: Wuhai -> Linhe (148.31km)
# INFO:root:step: Linhe -> Baotou (216.97km)
# INFO:root:step: Baotou -> Erdos (90.87km)
# INFO:root:step: Erdos -> Yulin (169.75km)
# INFO:root:step: Yulin -> Yanan (188.27km)
# INFO:root:step: Yanan -> Hohhot (505.01km)
# INFO:root:step: Hohhot -> Bayannaoer (721.84km)
# INFO:root:step: Bayannaoer -> Wuwei (103.61km)
# INFO:root:step: Wuwei -> Jinchang (78.25km)
# INFO:root:step: Jinchang -> Zhangye (158.10km)
# INFO:root:step: Zhangye -> Jiuquan (190.41km)
# INFO:root:step: Jiuquan -> Jiayuguan (19.60km)
# INFO:root:step: Jiayuguan -> Yumen (48.81km)
# INFO:root:step: Yumen -> Dunhuang (264.02km)
# INFO:root:step: Dunhuang -> Hami (311.36km)
# INFO:root:step: Hami -> Turpan (349.08km)
# INFO:root:step: Turpan -> Ürümqi (158.45km)
# INFO:root:step: Ürümqi -> Miquan (20.88km)
# INFO:root:step: Miquan -> Fukang (26.32km)
# INFO:root:step: Fukang -> Changji (50.72km)
# INFO:root:step: Changji -> Shihezi (107.77km)
# INFO:root:step: Shihezi -> Kuytun (92.19km)
# INFO:root:step: Kuytun -> Usu (55.00km)
# INFO:root:step: Usu -> Karamay (141.42km)
# INFO:root:step: Karamay -> Tacheng (193.23km)
# INFO:root:step: Tacheng -> Bole County (217.10km)
# INFO:root:step: Bole County -> Yining (125.45km)
# INFO:root:step: Yining -> Tumushuke (303.42km)
# INFO:root:step: Tumushuke -> Aksu (33.81km)
# INFO:root:step: Aksu -> Alaer (110.78km)
# INFO:root:step: Alaer -> Hotan (394.32km)
# INFO:root:step: Hotan -> Shache (284.41km)
# INFO:root:step: Shache -> Kashi (161.74km)
# INFO:root:step: Kashi -> Atushi (28.91km)
# INFO:root:step: Atushi -> Korla (873.94km)
# INFO:root:step: Korla -> Altay (696.77km)
# INFO:root:step: Altay -> Golmud (1384.94km)
# INFO:root:step: Golmud -> Xining (617.12km)
# INFO:root:step: Xining -> Lasa (1259.04km)
# INFO:root:step: Lasa -> Xigaze (219.18km)
# INFO:root:step: Xigaze -> Xingyi (1650.72km)
# INFO:root:step: Xingyi -> Guilin (543.67km)
# INFO:root:step: Guilin -> Shangzhi (2722.78km)
# INFO:root:step: Shangzhi -> Fujin (386.54km)
# INFO:root:step: Fujin -> Tongjiang (55.63km)
# INFO:root:step: Tongjiang -> Weihai (1411.62km)

# %% [markdown]
# # GREEDY with mutations

# %%
#  mutazione 
def insert_mutation(path):
    path = path.copy()
    i, j = random.sample(range(1, len(path) - 1), 2 ) 

    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path



initial_attempts = 1000
improvement_threshold = 0.001  # Soglia di miglioramento minimo percentuale
num_attempts = initial_attempts


# Algoritmo Greedy con miglioramento post-mutazione
for i in range(len(CITIES)):
    visited = np.full(len(CITIES), False)
    dist = DIST_MATRIX.copy()
    city = i
    visited[city] = True
    tsp = [int(city)]

    # Costruzione del percorso con algoritmo Greedy
    while not np.all(visited):
        dist[:, city] = np.inf
        closest = np.argmin(dist[city])
        visited[closest] = True
        city = closest
        tsp.append(int(city))

    tsp.append(tsp[0])  # Chiude il percorso
    cost = tsp_cost(tsp)

    if cost < best_cost:
        best_cost = cost
        best_tsp = tsp

    # Miglioramento post-mutazione con riduzione dinamica degli attempt
    last_cost = cost  
    for _ in range(num_attempts):
        new_tsp = insert_mutation(tsp)  # Usa insert_mutation
        new_cost = tsp_cost(new_tsp)
        
        if new_cost < cost:
            tsp = new_tsp
            cost = new_cost
            
            if cost < best_cost:
                best_cost = cost
                best_tsp = tsp

            # Riduci il numero di tentativi se i miglioramenti sono piccoli
            if abs(last_cost - cost) / last_cost < improvement_threshold:
                num_attempts = max(100, int(num_attempts * 0.9))  #  - 10% 
            last_cost = cost


# Output finale del miglior percorso
logging.info(f"Best path found has length {best_cost:.2f} km")

for c1, c2 in zip(best_tsp, best_tsp[1:]):
    logging.info(
        f"step: {CITIES.at[c1, 'name']} -> {CITIES.at[c2, 'name']} ({DIST_MATRIX[c1, c2]:.2f}km)"
    )
# Out:
# INFO:root:Best path found has length 61859.22 km
# INFO:root:step: Laiyang -> Laixi (18.76km)
# INFO:root:step: Laixi -> Pingdu (53.61km)
# INFO:root:step: Pingdu -> Laizhou (42.17km)
# INFO:root:step: Laizhou -> Zhaocheng (46.72km)
# INFO:root:step: Zhaocheng -> Longkou (32.95km)
# INFO:root:step: Longkou -> Penglai (40.08km)
# INFO:root:step: Penglai -> Qixia (58.11km)
# INFO:root:step: Qixia -> Yantai (55.76km)
# INFO:root:step: Yantai -> Weihai (61.97km)
# INFO:root:step: Weihai -> Wendeng (33.59km)
# INFO:root:step: Wendeng -> Rushan (59.18km)
# INFO:root:step: Rushan -> Haiyang (32.50km)
# INFO:root:step: Haiyang -> Jimo (77.32km)
# INFO:root:step: Jimo -> Qingdao (36.63km)
# INFO:root:step: Qingdao -> Jiaozhou (37.74km)
# INFO:root:step: Jiaozhou -> Gaomi (25.04km)
# INFO:root:step: Gaomi -> Anqiu (50.42km)
# INFO:root:step: Anqiu -> Weifang (33.17km)
# INFO:root:step: Weifang -> Changyi (29.12km)
# INFO:root:step: Changyi -> Shouguang (61.09km)
# INFO:root:step: Shouguang -> Qingzhou (29.10km)
# INFO:root:step: Qingzhou -> Yidu (2.04km)
# INFO:root:step: Yidu -> Zibo (39.23km)
# INFO:root:step: Zibo -> Zhoucun (18.83km)
# INFO:root:step: Zhoucun -> Zhangqiu (31.46km)
# INFO:root:step: Zhangqiu -> Boshan (44.53km)
# INFO:root:step: Boshan -> Laiwu (35.44km)
# INFO:root:step: Laiwu -> Xintai (34.49km)
# INFO:root:step: Xintai -> Taian (66.59km)
# INFO:root:step: Taian -> Jinan (53.25km)
# INFO:root:step: Jinan -> Liaocheng (95.99km)
# INFO:root:step: Liaocheng -> Linqing (53.34km)
# INFO:root:step: Linqing -> Nangong (64.34km)
# INFO:root:step: Nangong -> Jizhou (28.10km)
# INFO:root:step: Jizhou -> Hengshui (21.50km)
# INFO:root:step: Hengshui -> Shenzhou (33.22km)
# INFO:root:step: Shenzhou -> Xinji (34.58km)
# INFO:root:step: Xinji -> Gaocheng (33.50km)
# INFO:root:step: Gaocheng -> Luancheng (22.13km)
# INFO:root:step: Luancheng -> Shijiazhuang (24.07km)
# INFO:root:step: Shijiazhuang -> Luquan (14.80km)
# INFO:root:step: Luquan -> Xinle (47.41km)
# INFO:root:step: Xinle -> Dingzhou (27.75km)
# INFO:root:step: Dingzhou -> Anguo (31.16km)
# INFO:root:step: Anguo -> Baoding (52.29km)
# INFO:root:step: Baoding -> Renqiu (54.63km)
# INFO:root:step: Renqiu -> Hejian (27.87km)
# INFO:root:step: Hejian -> Botou (57.71km)
# INFO:root:step: Botou -> Cangzhou (39.44km)
# INFO:root:step: Cangzhou -> Huanghua (42.42km)
# INFO:root:step: Huanghua -> Gangdong (61.10km)
# INFO:root:step: Gangdong -> Tanggu (14.30km)
# INFO:root:step: Tanggu -> Hangu (27.25km)
# INFO:root:step: Hangu -> Tianjin (51.33km)
# INFO:root:step: Tianjin -> Langfang (62.33km)
# INFO:root:step: Langfang -> Huangcun (39.39km)
# INFO:root:step: Huangcun -> Beijing (22.18km)
# INFO:root:step: Beijing -> Tongzhou (20.79km)
# INFO:root:step: Tongzhou -> Yanjiao (15.33km)
# INFO:root:step: Yanjiao -> Sanhe (24.71km)
# INFO:root:step: Sanhe -> Shunyi (39.86km)
# INFO:root:step: Shunyi -> Changping (38.79km)
# INFO:root:step: Changping -> Mentougou (33.01km)
# INFO:root:step: Mentougou -> Fangshan (29.31km)
# INFO:root:step: Fangshan -> Zhuozhou (22.99km)
# INFO:root:step: Zhuozhou -> Gaobeidian (22.81km)
# INFO:root:step: Gaobeidian -> Bazhou (49.83km)
# INFO:root:step: Bazhou -> Tangshan (164.78km)
# INFO:root:step: Tangshan -> Linxi (22.43km)
# INFO:root:step: Linxi -> Zunhua (66.69km)
# INFO:root:step: Zunhua -> Chengde (86.30km)
# INFO:root:step: Chengde -> Lingyuan (126.80km)
# INFO:root:step: Lingyuan -> Chaoyang (94.76km)
# INFO:root:step: Chaoyang -> Beipiao (37.06km)
# INFO:root:step: Beipiao -> Fuxin (77.32km)
# INFO:root:step: Fuxin -> Beining (47.93km)
# INFO:root:step: Beining -> Panjin (51.12km)
# INFO:root:step: Panjin -> Linghai (58.76km)
# INFO:root:step: Linghai -> Jinzhou (21.62km)
# INFO:root:step: Jinzhou -> Huludao (50.11km)
# INFO:root:step: Huludao -> Xingcheng (13.96km)
# INFO:root:step: Xingcheng -> Qinhuangdao (121.57km)
# INFO:root:step: Qinhuangdao -> Wafangdian (206.78km)
# INFO:root:step: Wafangdian -> Pulandian (24.67km)
# INFO:root:step: Pulandian -> Dalian (59.65km)
# INFO:root:step: Dalian -> Zhuanghe (142.37km)
# INFO:root:step: Zhuanghe -> Gaizhou (94.94km)
# INFO:root:step: Gaizhou -> Dashiqiao (29.53km)
# INFO:root:step: Dashiqiao -> Yingkou (18.90km)
# INFO:root:step: Yingkou -> Jiupu (71.86km)
# INFO:root:step: Jiupu -> Anshan (5.55km)
# INFO:root:step: Anshan -> Liaoyang (26.23km)
# INFO:root:step: Liaoyang -> Dengta (21.32km)
# INFO:root:step: Dengta -> Sujiatun (25.18km)
# INFO:root:step: Sujiatun -> Shenyang (18.04km)
# INFO:root:step: Shenyang -> Yuhong (4.71km)
# INFO:root:step: Yuhong -> Dongling (4.99km)
# INFO:root:step: Dongling -> Fushun (27.15km)
# INFO:root:step: Fushun -> Tieling (48.02km)
# INFO:root:step: Tieling -> Tiefa (28.18km)
# INFO:root:step: Tiefa -> Xinmin (77.63km)
# INFO:root:step: Xinmin -> Liaozhong (54.94km)
# INFO:root:step: Liaozhong -> Benxi (87.58km)
# INFO:root:step: Benxi -> Fengcheng (101.30km)
# INFO:root:step: Fengcheng -> Dandong (45.45km)
# INFO:root:step: Dandong -> Donggang (36.20km)
# INFO:root:step: Donggang -> Tonghua (256.15km)
# INFO:root:step: Tonghua -> Baishan (45.88km)
# INFO:root:step: Baishan -> Linjiang (42.84km)
# INFO:root:step: Linjiang -> Huadian (128.51km)
# INFO:root:step: Huadian -> Panshi (56.40km)
# INFO:root:step: Panshi -> Meihekou (55.16km)
# INFO:root:step: Meihekou -> Liaoyuan (60.38km)
# INFO:root:step: Liaoyuan -> Siping (71.76km)
# INFO:root:step: Siping -> Gongzhuling (54.24km)
# INFO:root:step: Gongzhuling -> Changchun (59.12km)
# INFO:root:step: Changchun -> Jiutai (50.12km)
# INFO:root:step: Jiutai -> Dehui (43.68km)
# INFO:root:step: Dehui -> Yushu (75.90km)
# INFO:root:step: Yushu -> Wuchang (47.68km)
# INFO:root:step: Wuchang -> Shulan (59.07km)
# INFO:root:step: Shulan -> Jishu (17.91km)
# INFO:root:step: Jishu -> Jilin city (50.81km)
# INFO:root:step: Jilin city -> Jiaohe (65.64km)
# INFO:root:step: Jiaohe -> Dunhua (82.15km)
# INFO:root:step: Dunhua -> Helong (110.22km)
# INFO:root:step: Helong -> Longjing (42.88km)
# INFO:root:step: Longjing -> Yanji (14.70km)
# INFO:root:step: Yanji -> Tumen (26.45km)
# INFO:root:step: Tumen -> Huichun (46.09km)
# INFO:root:step: Huichun -> Ningan (179.31km)
# INFO:root:step: Ningan -> Hailin (26.54km)
# INFO:root:step: Hailin -> Mudanjiang (18.30km)
# INFO:root:step: Mudanjiang -> Muleng (81.67km)
# INFO:root:step: Muleng -> Hengshan (43.08km)
# INFO:root:step: Hengshan -> Jixi (12.77km)
# INFO:root:step: Jixi -> Didao (8.52km)
# INFO:root:step: Didao -> Qitaihe (52.26km)
# INFO:root:step: Qitaihe -> Mishan (84.93km)
# INFO:root:step: Mishan -> Hulin (85.55km)
# INFO:root:step: Hulin -> Baoshan (148.92km)
# INFO:root:step: Baoshan -> Shuangyashan (11.53km)
# INFO:root:step: Shuangyashan -> Jiamusi (78.45km)
# INFO:root:step: Jiamusi -> Hegang (63.39km)
# INFO:root:step: Hegang -> Nancha (88.49km)
# INFO:root:step: Nancha -> Yichun (72.65km)
# INFO:root:step: Yichun -> Tieli (108.21km)
# INFO:root:step: Tieli -> Suihua (89.11km)
# INFO:root:step: Suihua -> Hailun (91.24km)
# INFO:root:step: Hailun -> Beian (94.46km)
# INFO:root:step: Beian -> Wudalianchi (62.24km)
# INFO:root:step: Wudalianchi -> Nehe (99.17km)
# INFO:root:step: Nehe -> Qiqihar (142.80km)
# INFO:root:step: Qiqihar -> Hulan Ergi (33.36km)
# INFO:root:step: Hulan Ergi -> Longjiang (35.60km)
# INFO:root:step: Longjiang -> Zalantun (81.11km)
# INFO:root:step: Zalantun -> Yakeshi (204.36km)
# INFO:root:step: Yakeshi -> Hailar (74.46km)
# INFO:root:step: Hailar -> Hulunbeir (3.42km)
# INFO:root:step: Hulunbeir -> Zhalainuoer (147.71km)
# INFO:root:step: Zhalainuoer -> Manzhouli (24.90km)
# INFO:root:step: Manzhouli -> Genhe (320.38km)
# INFO:root:step: Genhe -> Jiagedagi (186.53km)
# INFO:root:step: Jiagedagi -> Heihe (239.79km)
# INFO:root:step: Heihe -> Ranghulu (446.36km)
# INFO:root:step: Ranghulu -> Saertu (13.95km)
# INFO:root:step: Saertu -> Longfeng (8.21km)
# INFO:root:step: Longfeng -> Honggang (20.45km)
# INFO:root:step: Honggang -> Anda (35.45km)
# INFO:root:step: Anda -> Zhaodong (62.75km)
# INFO:root:step: Zhaodong -> Harbin (62.99km)
# INFO:root:step: Harbin -> Acheng (33.60km)
# INFO:root:step: Acheng -> Shuangcheng (57.24km)
# INFO:root:step: Shuangcheng -> Zhaoyuan (96.34km)
# INFO:root:step: Zhaoyuan -> Songyuan (44.10km)
# INFO:root:step: Songyuan -> Qianguo (4.81km)
# INFO:root:step: Qianguo -> Qianan (63.65km)
# INFO:root:step: Qianan -> Taonan (104.56km)
# INFO:root:step: Taonan -> Baicheng (32.38km)
# INFO:root:step: Baicheng -> Ulanhot (78.08km)
# INFO:root:step: Ulanhot -> Tongliao (279.51km)
# INFO:root:step: Tongliao -> Shuangliao (100.03km)
# INFO:root:step: Shuangliao -> Chifeng (396.55km)
# INFO:root:step: Chifeng -> Xilinhot (298.76km)
# INFO:root:step: Xilinhot -> Zhangjiakou (359.34km)
# INFO:root:step: Zhangjiakou -> Ulanchabu (152.53km)
# INFO:root:step: Ulanchabu -> Jining (5.75km)
# INFO:root:step: Jining -> Fengzhen (65.65km)
# INFO:root:step: Fengzhen -> Datong (42.93km)
# INFO:root:step: Datong -> Shuozhou (113.95km)
# INFO:root:step: Shuozhou -> Yuanping County (70.83km)
# INFO:root:step: Yuanping County -> Xinzhou (34.39km)
# INFO:root:step: Xinzhou -> Taiyuan (62.77km)
# INFO:root:step: Taiyuan -> Jinzhong (26.27km)
# INFO:root:step: Jinzhong -> Yuci (0.47km)
# INFO:root:step: Yuci -> Gujiao (65.64km)
# INFO:root:step: Gujiao -> Jiexiu (97.44km)
# INFO:root:step: Jiexiu -> Huozhou (53.25km)
# INFO:root:step: Huozhou -> Fenyang (58.32km)
# INFO:root:step: Fenyang -> Lüliang (0.00km)
# INFO:root:step: Lüliang -> Linfen (0.48km)
# INFO:root:step: Linfen -> Houma (58.22km)
# INFO:root:step: Houma -> Yuncheng (70.04km)
# INFO:root:step: Yuncheng -> Sanmenxia (22.51km)
# INFO:root:step: Sanmenxia -> Lingbao (39.08km)
# INFO:root:step: Lingbao -> Yongji (53.80km)
# INFO:root:step: Yongji -> Hancheng (66.96km)
# INFO:root:step: Hancheng -> Tongchuan (130.45km)
# INFO:root:step: Tongchuan -> Weinan (73.53km)
# INFO:root:step: Weinan -> Xian (60.79km)
# INFO:root:step: Xian -> Xianyang (21.49km)
# INFO:root:step: Xianyang -> Xingping (20.80km)
# INFO:root:step: Xingping -> Baoji (102.81km)
# INFO:root:step: Baoji -> Hanzhong (139.44km)
# INFO:root:step: Hanzhong -> Guangyuan (133.55km)
# INFO:root:step: Guangyuan -> Langzhong (94.61km)
# INFO:root:step: Langzhong -> Bazhong (80.98km)
# INFO:root:step: Bazhong -> Daxian (98.59km)
# INFO:root:step: Daxian -> Dazhou (6.21km)
# INFO:root:step: Dazhou -> Wanyuan (95.85km)
# INFO:root:step: Wanyuan -> Ankang (125.71km)
# INFO:root:step: Ankang -> Shangluo (157.62km)
# INFO:root:step: Shangluo -> Shiyan (164.24km)
# INFO:root:step: Shiyan -> Danjiangkou (67.65km)
# INFO:root:step: Danjiangkou -> Laohekou (23.26km)
# INFO:root:step: Laohekou -> Dengzhou (54.01km)
# INFO:root:step: Dengzhou -> Nanyang (52.09km)
# INFO:root:step: Nanyang -> Wugang (98.60km)
# INFO:root:step: Wugang -> Pingdingshan (52.65km)
# INFO:root:step: Pingdingshan -> Yuzhou (49.67km)
# INFO:root:step: Yuzhou -> Xinzheng (8.28km)
# INFO:root:step: Xinzheng -> Xinmi (29.62km)
# INFO:root:step: Xinmi -> Xingyang (32.02km)
# INFO:root:step: Xingyang -> Zhengzhou (29.53km)
# INFO:root:step: Zhengzhou -> Changge (60.11km)
# INFO:root:step: Changge -> Xuchang (22.12km)
# INFO:root:step: Xuchang -> Luohe (53.57km)
# INFO:root:step: Luohe -> Zhoukou (56.22km)
# INFO:root:step: Zhoukou -> Jieshou (79.70km)
# INFO:root:step: Jieshou -> Bozhou (78.60km)
# INFO:root:step: Bozhou -> Yongcheng (64.17km)
# INFO:root:step: Yongcheng -> Huaibei (27.82km)
# INFO:root:step: Huaibei -> Suzhou (43.62km)
# INFO:root:step: Suzhou -> Xuzhou (74.35km)
# INFO:root:step: Xuzhou -> Xiazhen (61.45km)
# INFO:root:step: Xiazhen -> Tengzhou (30.30km)
# INFO:root:step: Tengzhou -> Zoucheng (38.23km)
# INFO:root:step: Zoucheng -> Zouxian (2.66km)
# INFO:root:step: Zouxian -> Yanzhou (18.97km)
# INFO:root:step: Yanzhou -> Qufu (14.68km)
# INFO:root:step: Qufu -> Yucheng (87.63km)
# INFO:root:step: Yucheng -> Shangqiu (92.74km)
# INFO:root:step: Shangqiu -> Heze (89.35km)
# INFO:root:step: Heze -> Xiangcheng (41.54km)
# INFO:root:step: Xiangcheng -> Puyang (37.86km)
# INFO:root:step: Puyang -> Anyang (70.80km)
# INFO:root:step: Anyang -> Hebi (18.59km)
# INFO:root:step: Hebi -> Linzhou (33.37km)
# INFO:root:step: Linzhou -> Linshui (56.73km)
# INFO:root:step: Linshui -> Wuan (27.76km)
# INFO:root:step: Wuan -> Handan (29.15km)
# INFO:root:step: Handan -> Shahe (38.25km)
# INFO:root:step: Shahe -> Xingtai (17.48km)
# INFO:root:step: Xingtai -> Yangquan (120.44km)
# INFO:root:step: Yangquan -> Changzhi (200.33km)
# INFO:root:step: Changzhi -> Gaoping (36.54km)
# INFO:root:step: Gaoping -> Jincheng (34.58km)
# INFO:root:step: Jincheng -> Jiaozuo (45.00km)
# INFO:root:step: Jiaozuo -> Qinyang (32.00km)
# INFO:root:step: Qinyang -> Mengzhou (23.01km)
# INFO:root:step: Mengzhou -> Yanshi (20.34km)
# INFO:root:step: Yanshi -> Xiaoyi (15.79km)
# INFO:root:step: Xiaoyi -> Gongyi (1.57km)
# INFO:root:step: Gongyi -> Dengfeng (34.25km)
# INFO:root:step: Dengfeng -> Ruzhou (38.72km)
# INFO:root:step: Ruzhou -> Jiyuan (105.73km)
# INFO:root:step: Jiyuan -> Yima (76.65km)
# INFO:root:step: Yima -> Huixian (193.98km)
# INFO:root:step: Huixian -> Xinxiang (16.75km)
# INFO:root:step: Xinxiang -> Weihui (20.63km)
# INFO:root:step: Weihui -> Kaifeng (70.25km)
# INFO:root:step: Kaifeng -> Zhumadian (210.37km)
# INFO:root:step: Zhumadian -> Xinyang (93.17km)
# INFO:root:step: Xinyang -> Guangshui (56.94km)
# INFO:root:step: Guangshui -> Anlu (49.90km)
# INFO:root:step: Anlu -> Yingcheng (38.61km)
# INFO:root:step: Yingcheng -> Xiaogan (31.89km)
# INFO:root:step: Xiaogan -> Hanchuan (31.76km)
# INFO:root:step: Hanchuan -> Wuhan (42.71km)
# INFO:root:step: Wuhan -> Ezhou (57.35km)
# INFO:root:step: Ezhou -> Huangzhou (6.25km)
# INFO:root:step: Huangzhou -> Huangshi (34.39km)
# INFO:root:step: Huangshi -> Daye County (17.41km)
# INFO:root:step: Daye County -> Wuxue (61.31km)
# INFO:root:step: Wuxue -> Ruichang (21.77km)
# INFO:root:step: Ruichang -> Jiujiang (31.37km)
# INFO:root:step: Jiujiang -> Hejin (101.97km)
# INFO:root:step: Hejin -> Leping (45.97km)
# INFO:root:step: Leping -> Jingdezhen (33.93km)
# INFO:root:step: Jingdezhen -> Dexing (52.84km)
# INFO:root:step: Dexing -> Shangrao (65.19km)
# INFO:root:step: Shangrao -> Jiangshan (70.53km)
# INFO:root:step: Jiangshan -> Quzhou (35.26km)
# INFO:root:step: Quzhou -> Lanxi (64.69km)
# INFO:root:step: Lanxi -> Jinhua (20.34km)
# INFO:root:step: Jinhua -> Yongkang (44.21km)
# INFO:root:step: Yongkang -> Dongyang (44.47km)
# INFO:root:step: Dongyang -> Yiwu (31.77km)
# INFO:root:step: Yiwu -> Zhuji (23.72km)
# INFO:root:step: Zhuji -> Shaoxing (45.28km)
# INFO:root:step: Shaoxing -> Shangyu (28.68km)
# INFO:root:step: Shangyu -> Yuyao (27.58km)
# INFO:root:step: Yuyao -> Cixi (15.22km)
# INFO:root:step: Cixi -> Ningbo (44.08km)
# INFO:root:step: Ningbo -> Fenghua (28.57km)
# INFO:root:step: Fenghua -> Shengzhou (58.37km)
# INFO:root:step: Shengzhou -> Linhai (88.94km)
# INFO:root:step: Linhai -> Huangyan (25.11km)
# INFO:root:step: Huangyan -> Luqiao (14.89km)
# INFO:root:step: Luqiao -> Jiaojiang (13.03km)
# INFO:root:step: Jiaojiang -> Wenling (35.72km)
# INFO:root:step: Wenling -> Yueqing (47.25km)
# INFO:root:step: Yueqing -> Wenzhou (32.43km)
# INFO:root:step: Wenzhou -> Ruian (19.74km)
# INFO:root:step: Ruian -> Fuding (81.60km)
# INFO:root:step: Fuding -> Fuan (56.69km)
# INFO:root:step: Fuan -> Ningde (49.39km)
# INFO:root:step: Ningde -> Changle (82.94km)
# INFO:root:step: Changle -> Fuqing (28.34km)
# INFO:root:step: Fuqing -> Nantongkuang (27.75km)
# INFO:root:step: Nantongkuang -> Putian (61.08km)
# INFO:root:step: Putian -> Bantou (34.85km)
# INFO:root:step: Bantou -> Quanzhou (53.03km)
# INFO:root:step: Quanzhou -> Jinjiang (8.92km)
# INFO:root:step: Jinjiang -> Qingyang (0.00km)
# INFO:root:step: Qingyang -> Shishi (11.92km)
# INFO:root:step: Shishi -> Nan'an (36.33km)
# INFO:root:step: Nan'an -> Xiamen (64.51km)
# INFO:root:step: Xiamen -> Longhai (32.71km)
# INFO:root:step: Longhai -> Zhangzhou (17.13km)
# INFO:root:step: Zhangzhou -> Zhangping (88.34km)
# INFO:root:step: Zhangping -> Longyan (40.61km)
# INFO:root:step: Longyan -> Yongan (94.28km)
# INFO:root:step: Yongan -> Sanming (36.01km)
# INFO:root:step: Sanming -> Nanping (73.67km)
# INFO:root:step: Nanping -> Jian'ou (47.30km)
# INFO:root:step: Jian'ou -> Jianyang (38.63km)
# INFO:root:step: Jianyang -> Wuyishan (48.94km)
# INFO:root:step: Wuyishan -> Shaowu (73.82km)
# INFO:root:step: Shaowu -> Guixi (112.99km)
# INFO:root:step: Guixi -> Yingtai (17.95km)
# INFO:root:step: Yingtai -> Linchuan (70.96km)
# INFO:root:step: Linchuan -> Fuzhou (2.10km)
# INFO:root:step: Fuzhou -> Zhangshu (80.43km)
# INFO:root:step: Zhangshu -> Gaoan (42.06km)
# INFO:root:step: Gaoan -> Nanchang (57.64km)
# INFO:root:step: Nanchang -> Xinyu (134.92km)
# INFO:root:step: Xinyu -> Jian (74.56km)
# INFO:root:step: Jian -> Jinggangshan (107.38km)
# INFO:root:step: Jinggangshan -> Zixing (99.21km)
# INFO:root:step: Zixing -> Chenzhou (41.42km)
# INFO:root:step: Chenzhou -> Leiyang (71.27km)
# INFO:root:step: Leiyang -> Changning (42.60km)
# INFO:root:step: Changning -> Qidong (59.18km)
# INFO:root:step: Qidong -> Hengyang (51.17km)
# INFO:root:step: Hengyang -> Xiangxiang (94.71km)
# INFO:root:step: Xiangxiang -> Shaoshan (19.25km)
# INFO:root:step: Shaoshan -> Xiangtan (41.89km)
# INFO:root:step: Xiangtan -> Zhuzhou (24.73km)
# INFO:root:step: Zhuzhou -> Liling (37.92km)
# INFO:root:step: Liling -> Xiangdong (24.89km)
# INFO:root:step: Xiangdong -> Pingxiang (11.08km)
# INFO:root:step: Pingxiang -> Liuyang (61.91km)
# INFO:root:step: Liuyang -> Changsha (64.65km)
# INFO:root:step: Changsha -> Miluo (68.24km)
# INFO:root:step: Miluo -> Yueyang (63.40km)
# INFO:root:step: Yueyang -> Linxiang (36.89km)
# INFO:root:step: Linxiang -> Honghu (39.16km)
# INFO:root:step: Honghu -> Chibi (43.13km)
# INFO:root:step: Chibi -> Xianning (35.85km)
# INFO:root:step: Xianning -> Xiantao (92.61km)
# INFO:root:step: Xiantao -> Tianmen (41.69km)
# INFO:root:step: Tianmen -> Qianjiang (36.35km)
# INFO:root:step: Qianjiang -> Shashi (64.60km)
# INFO:root:step: Shashi -> Songzi (1.69km)
# INFO:root:step: Songzi -> Jingzhou (4.61km)
# INFO:root:step: Jingzhou -> Buhe (9.67km)
# INFO:root:step: Buhe -> Zhijiang (49.36km)
# INFO:root:step: Zhijiang -> Zhicheng (28.62km)
# INFO:root:step: Zhicheng -> Yichang (48.71km)
# INFO:root:step: Yichang -> Dangyang (50.39km)
# INFO:root:step: Dangyang -> Jingmen (44.64km)
# INFO:root:step: Jingmen -> Yingzhong (40.32km)
# INFO:root:step: Yingzhong -> Zhongxiang (0.49km)
# INFO:root:step: Zhongxiang -> Yicheng (68.07km)
# INFO:root:step: Yicheng -> Xiangfan (36.20km)
# INFO:root:step: Xiangfan -> Zaoyang (59.80km)
# INFO:root:step: Zaoyang -> Suizhou (74.14km)
# INFO:root:step: Suizhou -> Macheng (169.27km)
# INFO:root:step: Macheng -> Luan (151.60km)
# INFO:root:step: Luan -> Hefei (76.57km)
# INFO:root:step: Hefei -> Feidong (16.48km)
# INFO:root:step: Feidong -> Chaohu (49.94km)
# INFO:root:step: Chaohu -> Wuhu (55.01km)
# INFO:root:step: Wuhu -> Maanshan (43.41km)
# INFO:root:step: Maanshan -> Nanjing (45.44km)
# INFO:root:step: Nanjing -> Jurong (37.28km)
# INFO:root:step: Jurong -> Yizheng (37.63km)
# INFO:root:step: Yizheng -> Zhenjiang (22.37km)
# INFO:root:step: Zhenjiang -> Yangzhou (19.96km)
# INFO:root:step: Yangzhou -> Jiangdu (13.58km)
# INFO:root:step: Jiangdu -> Taizhou (32.68km)
# INFO:root:step: Taizhou -> Jiangyan (22.02km)
# INFO:root:step: Jiangyan -> Taixing (39.94km)
# INFO:root:step: Taixing -> Jingjiang (31.10km)
# INFO:root:step: Jingjiang -> Jiangyin (15.38km)
# INFO:root:step: Jiangyin -> Zhangjiagang (28.05km)
# INFO:root:step: Zhangjiagang -> Nantong (29.79km)
# INFO:root:step: Nantong -> Changshu (41.84km)
# INFO:root:step: Changshu -> Kunshan (36.00km)
# INFO:root:step: Kunshan -> Taicang (15.26km)
# INFO:root:step: Taicang -> Shanghai (43.18km)
# INFO:root:step: Shanghai -> Pinghu (73.00km)
# INFO:root:step: Pinghu -> Jiaxing (26.69km)
# INFO:root:step: Jiaxing -> Tongxiang (25.70km)
# INFO:root:step: Tongxiang -> Haining (18.16km)
# INFO:root:step: Haining -> Wujiang (56.85km)
# INFO:root:step: Wujiang -> Huzhou (53.68km)
# INFO:root:step: Huzhou -> Deqing (35.53km)
# INFO:root:step: Deqing -> Hangzhou (34.36km)
# INFO:root:step: Hangzhou -> Fuyang (30.23km)
# INFO:root:step: Fuyang -> Lin'an (29.63km)
# INFO:root:step: Lin'an -> Ningguo (82.35km)
# INFO:root:step: Ningguo -> Xuanzhou (41.97km)
# INFO:root:step: Xuanzhou -> Yixing (54.41km)
# INFO:root:step: Yixing -> Liyang (47.55km)
# INFO:root:step: Liyang -> Jintan (30.68km)
# INFO:root:step: Jintan -> Yunyang (33.18km)
# INFO:root:step: Yunyang -> Danyang (0.63km)
# INFO:root:step: Danyang -> Changzhou (45.29km)
# INFO:root:step: Changzhou -> Wuxi (38.35km)
# INFO:root:step: Wuxi -> Rugao (92.16km)
# INFO:root:step: Rugao -> Dongtai (56.82km)
# INFO:root:step: Dongtai -> Dafeng (40.67km)
# INFO:root:step: Dafeng -> Yancheng (35.75km)
# INFO:root:step: Yancheng -> Tianchang (48.86km)
# INFO:root:step: Tianchang -> Xinghua (31.62km)
# INFO:root:step: Xinghua -> Gaoyou (42.14km)
# INFO:root:step: Gaoyou -> Huaian (84.51km)
# INFO:root:step: Huaian -> Huaiyin (13.07km)
# INFO:root:step: Huaiyin -> Suqian (79.51km)
# INFO:root:step: Suqian -> Xinyi (48.76km)
# INFO:root:step: Xinyi -> Pizhou (31.88km)
# INFO:root:step: Pizhou -> Zaozhuang (72.01km)
# INFO:root:step: Zaozhuang -> Feicheng (55.44km)
# INFO:root:step: Feicheng -> Linyi (40.53km)
# INFO:root:step: Linyi -> Heilin (52.19km)
# INFO:root:step: Heilin -> Lianyungang (51.61km)
# INFO:root:step: Lianyungang -> Rizhao (95.64km)
# INFO:root:step: Rizhao -> Zhucheng (62.46km)
# INFO:root:step: Zhucheng -> Jiaonan (53.74km)
# INFO:root:step: Jiaonan -> Dongying (221.08km)
# INFO:root:step: Dongying -> Hekou (5.62km)
# INFO:root:step: Hekou -> Binzhou (51.12km)
# INFO:root:step: Binzhou -> Leling (80.30km)
# INFO:root:step: Leling -> Dezhou (86.85km)
# INFO:root:step: Dezhou -> Bengbu (507.97km)
# INFO:root:step: Bengbu -> Huainan (48.31km)
# INFO:root:step: Huainan -> Mingguang (95.04km)
# INFO:root:step: Mingguang -> Chuzhou (60.17km)
# INFO:root:step: Chuzhou -> Lujiang (152.75km)
# INFO:root:step: Lujiang -> Tongcheng (46.95km)
# INFO:root:step: Tongcheng -> Anqing (50.06km)
# INFO:root:step: Anqing -> Chizhou (44.47km)
# INFO:root:step: Chizhou -> Tongling (43.94km)
# INFO:root:step: Tongling -> Huangshan (145.58km)
# INFO:root:step: Huangshan -> Jiande (103.56km)
# INFO:root:step: Jiande -> Lishui (127.05km)
# INFO:root:step: Lishui -> Zhoushan (280.09km)
# INFO:root:step: Zhoushan -> Ruijin (766.94km)
# INFO:root:step: Ruijin -> Ganzhou (108.52km)
# INFO:root:step: Ganzhou -> Nankang (36.02km)
# INFO:root:step: Nankang -> Nanxiong (76.34km)
# INFO:root:step: Nanxiong -> Shaoguan (80.73km)
# INFO:root:step: Shaoguan -> Maba (13.29km)
# INFO:root:step: Maba -> Lecheng (56.00km)
# INFO:root:step: Lecheng -> Lianzhou (106.01km)
# INFO:root:step: Lianzhou -> Hezhou (93.17km)
# INFO:root:step: Hezhou -> Wuzhou (106.27km)
# INFO:root:step: Wuzhou -> Cenxi (68.29km)
# INFO:root:step: Cenxi -> Luoding (59.07km)
# INFO:root:step: Luoding -> Yunfu (51.30km)
# INFO:root:step: Yunfu -> Gaoyao (44.09km)
# INFO:root:step: Gaoyao -> Zhaoqing (2.13km)
# INFO:root:step: Zhaoqing -> Sihui (40.92km)
# INFO:root:step: Sihui -> Xinan (29.06km)
# INFO:root:step: Xinan -> Foshan (28.21km)
# INFO:root:step: Foshan -> Guangzhou (16.64km)
# INFO:root:step: Guangzhou -> Huangpu (17.55km)
# INFO:root:step: Huangpu -> Shiqiao (18.76km)
# INFO:root:step: Shiqiao -> Daliang (15.81km)
# INFO:root:step: Daliang -> Xiaolan (7.32km)
# INFO:root:step: Xiaolan -> Zhongshan (28.60km)
# INFO:root:step: Zhongshan -> Jiangmen (28.32km)
# INFO:root:step: Jiangmen -> Shaping (24.39km)
# INFO:root:step: Shaping -> Kaiping (52.61km)
# INFO:root:step: Kaiping -> Taicheng (15.01km)
# INFO:root:step: Taicheng -> Taishan (1.76km)
# INFO:root:step: Taishan -> Enping (50.38km)
# INFO:root:step: Enping -> Yangjiang (50.23km)
# INFO:root:step: Yangjiang -> Yangchun (40.42km)
# INFO:root:step: Yangchun -> Maoming (99.24km)
# INFO:root:step: Maoming -> Gaozhou (3.29km)
# INFO:root:step: Gaozhou -> Huazhou (38.46km)
# INFO:root:step: Huazhou -> Wuchuan (25.92km)
# INFO:root:step: Wuchuan -> Zhanjiang (47.32km)
# INFO:root:step: Zhanjiang -> Dongli (39.87km)
# INFO:root:step: Dongli -> Leizhou (29.35km)
# INFO:root:step: Leizhou -> Lianjiang (93.64km)
# INFO:root:step: Lianjiang -> Beiliu (87.90km)
# INFO:root:step: Beiliu -> Guiping (106.54km)
# INFO:root:step: Guiping -> Guigang (57.96km)
# INFO:root:step: Guigang -> Laibin (75.34km)
# INFO:root:step: Laibin -> Heshan (40.94km)
# INFO:root:step: Heshan -> Liuzhou (63.57km)
# INFO:root:step: Liuzhou -> Yizhou (70.68km)
# INFO:root:step: Yizhou -> Hechi (56.39km)
# INFO:root:step: Hechi -> Jinchengjiang (25.82km)
# INFO:root:step: Jinchengjiang -> Baise (151.73km)
# INFO:root:step: Baise -> Chongzuo (181.34km)
# INFO:root:step: Chongzuo -> Nanning (107.71km)
# INFO:root:step: Nanning -> Qinzhou (101.17km)
# INFO:root:step: Qinzhou -> Fangchenggang (50.96km)
# INFO:root:step: Fangchenggang -> Dongxing (34.49km)
# INFO:root:step: Dongxing -> Beihai (117.15km)
# INFO:root:step: Beihai -> Lingao (184.02km)
# INFO:root:step: Lingao -> Danzhou (46.50km)
# INFO:root:step: Danzhou -> Wuzhishan (80.72km)
# INFO:root:step: Wuzhishan -> Sanya (60.28km)
# INFO:root:step: Sanya -> Wanning (114.95km)
# INFO:root:step: Wanning -> Qionghai (49.66km)
# INFO:root:step: Qionghai -> Wenchang (50.91km)
# INFO:root:step: Wenchang -> Qiongshan (57.43km)
# INFO:root:step: Qiongshan -> Dongfang (204.33km)
# INFO:root:step: Dongfang -> Zhuhai (621.75km)
# INFO:root:step: Zhuhai -> Shenzhen (62.22km)
# INFO:root:step: Shenzhen -> Danshui (46.21km)
# INFO:root:step: Danshui -> Pingshan (30.86km)
# INFO:root:step: Pingshan -> Huizhou (30.38km)
# INFO:root:step: Huizhou -> Luoyang (15.82km)
# INFO:root:step: Luoyang -> Shilong (46.56km)
# INFO:root:step: Shilong -> Dongguan (12.21km)
# INFO:root:step: Dongguan -> Humen (22.23km)
# INFO:root:step: Humen -> Zengcheng (50.44km)
# INFO:root:step: Zengcheng -> Conghua (43.29km)
# INFO:root:step: Conghua -> Yingde (62.70km)
# INFO:root:step: Yingde -> Qingyuan (63.86km)
# INFO:root:step: Qingyuan -> Heyuan (169.61km)
# INFO:root:step: Heyuan -> Haicheng (106.46km)
# INFO:root:step: Haicheng -> Shanwei (22.24km)
# INFO:root:step: Shanwei -> Jieshi (48.46km)
# INFO:root:step: Jieshi -> Jiazi (24.52km)
# INFO:root:step: Jiazi -> Huicheng (29.50km)
# INFO:root:step: Huicheng -> Lufeng (15.62km)
# INFO:root:step: Lufeng -> Puning (15.32km)
# INFO:root:step: Puning -> Jieyang (34.16km)
# INFO:root:step: Jieyang -> Mianchang (18.68km)
# INFO:root:step: Mianchang -> Haimen (6.95km)
# INFO:root:step: Haimen -> Shantou (19.80km)
# INFO:root:step: Shantou -> Anbu (10.02km)
# INFO:root:step: Anbu -> Chenghai (9.26km)
# INFO:root:step: Chenghai -> Chaozhou (25.82km)
# INFO:root:step: Chaozhou -> Huanggang (36.74km)
# INFO:root:step: Huanggang -> Meizhou (114.89km)
# INFO:root:step: Meizhou -> Xingning (49.38km)
# INFO:root:step: Xingning -> Hepo (82.33km)
# INFO:root:step: Hepo -> Yongzhou (527.51km)
# INFO:root:step: Yongzhou -> Shaoyang (94.16km)
# INFO:root:step: Shaoyang -> Lengshuijiang (78.43km)
# INFO:root:step: Lengshuijiang -> Lianyuan (23.78km)
# INFO:root:step: Lianyuan -> Loudi (33.10km)
# INFO:root:step: Loudi -> Yiyang (100.27km)
# INFO:root:step: Yiyang -> Yuanjiang (25.96km)
# INFO:root:step: Yuanjiang -> Changde (71.76km)
# INFO:root:step: Changde -> Jinshi (68.52km)
# INFO:root:step: Jinshi -> Shishou (54.38km)
# INFO:root:step: Shishou -> Rongcheng (47.48km)
# INFO:root:step: Rongcheng -> Zhangjiajie (244.59km)
# INFO:root:step: Zhangjiajie -> Jishou (116.99km)
# INFO:root:step: Jishou -> Huaihua (86.96km)
# INFO:root:step: Huaihua -> Hongjiang (49.01km)
# INFO:root:step: Hongjiang -> Tongren (105.28km)
# INFO:root:step: Tongren -> Kaili (171.01km)
# INFO:root:step: Kaili -> Fuquan (44.96km)
# INFO:root:step: Fuquan -> Duyun (45.94km)
# INFO:root:step: Duyun -> Guiyang (86.88km)
# INFO:root:step: Guiyang -> Qingzhen (25.46km)
# INFO:root:step: Qingzhen -> Anshun (63.02km)
# INFO:root:step: Anshun -> Liupanshui (112.83km)
# INFO:root:step: Liupanshui -> Xuanwei (84.81km)
# INFO:root:step: Xuanwei -> Qujing (88.80km)
# INFO:root:step: Qujing -> Jinma (113.70km)
# INFO:root:step: Jinma -> Kunming (5.17km)
# INFO:root:step: Kunming -> Majie (5.05km)
# INFO:root:step: Majie -> Anning (22.60km)
# INFO:root:step: Anning -> Haikou (13.15km)
# INFO:root:step: Haikou -> Longquan (48.84km)
# INFO:root:step: Longquan -> Yuxi (53.34km)
# INFO:root:step: Yuxi -> Zhoucheng (2.02km)
# INFO:root:step: Zhoucheng -> Kaiyuan (100.89km)
# INFO:root:step: Kaiyuan -> Gejiu (37.95km)
# INFO:root:step: Gejiu -> Simao (232.06km)
# INFO:root:step: Simao -> Jinghong (89.81km)
# INFO:root:step: Jinghong -> Lincang (223.45km)
# INFO:root:step: Lincang -> Luxi (163.28km)
# INFO:root:step: Luxi -> Ruili (90.10km)
# INFO:root:step: Ruili -> Dali (298.11km)
# INFO:root:step: Dali -> Chuxiong (158.08km)
# INFO:root:step: Chuxiong -> Lucheng (1.18km)
# INFO:root:step: Lucheng -> Panzhihua (172.21km)
# INFO:root:step: Panzhihua -> Xichang (156.59km)
# INFO:root:step: Xichang -> Zhaotong (153.31km)
# INFO:root:step: Zhaotong -> Wufeng (112.57km)
# INFO:root:step: Wufeng -> Bijie (44.91km)
# INFO:root:step: Bijie -> Renhuai (124.73km)
# INFO:root:step: Renhuai -> Zunyi (50.81km)
# INFO:root:step: Zunyi -> Chishui (155.42km)
# INFO:root:step: Chishui -> Luzhou (44.67km)
# INFO:root:step: Luzhou -> Yongchuan (73.96km)
# INFO:root:step: Yongchuan -> Daan (12.22km)
# INFO:root:step: Daan -> Jiangjin (25.77km)
# INFO:root:step: Jiangjin -> Chongqing (44.26km)
# INFO:root:step: Chongqing -> Beibei (31.85km)
# INFO:root:step: Beibei -> Hechuan (22.32km)
# INFO:root:step: Hechuan -> Guang'an (66.31km)
# INFO:root:step: Guang'an -> Huaying (19.30km)
# INFO:root:step: Huaying -> Nanchong (77.66km)
# INFO:root:step: Nanchong -> Suining (63.84km)
# INFO:root:step: Suining -> Ziyang (95.88km)
# INFO:root:step: Ziyang -> Neijiang (73.64km)
# INFO:root:step: Neijiang -> Zigong (32.92km)
# INFO:root:step: Zigong -> Yibin (72.76km)
# INFO:root:step: Yibin -> Leshan (119.92km)
# INFO:root:step: Leshan -> Emeishan (25.23km)
# INFO:root:step: Emeishan -> Yaan (57.23km)
# INFO:root:step: Yaan -> Qionglai (61.07km)
# INFO:root:step: Qionglai -> Chongzhou (30.90km)
# INFO:root:step: Chongzhou -> Dujiangyan (34.18km)
# INFO:root:step: Dujiangyan -> Pengzhou (42.43km)
# INFO:root:step: Pengzhou -> Guanghan (30.26km)
# INFO:root:step: Guanghan -> Deyang (21.12km)
# INFO:root:step: Deyang -> Mianzhu (29.52km)
# INFO:root:step: Mianzhu -> Shifang (0.00km)
# INFO:root:step: Shifang -> Mianyang (56.29km)
# INFO:root:step: Mianyang -> Jiangyou (33.28km)
# INFO:root:step: Jiangyou -> Chengdu (138.55km)
# INFO:root:step: Chengdu -> Meishan (71.85km)
# INFO:root:step: Meishan -> Fuling (341.64km)
# INFO:root:step: Fuling -> Nanchuan (139.30km)
# INFO:root:step: Nanchuan -> Lichuan (87.67km)
# INFO:root:step: Lichuan -> Enshi (52.96km)
# INFO:root:step: Enshi -> Wanxian (118.84km)
# INFO:root:step: Wanxian -> Longnan (435.75km)
# INFO:root:step: Longnan -> Xining (458.31km)
# INFO:root:step: Xining -> Tianshui (424.25km)
# INFO:root:step: Tianshui -> Pingliang (135.97km)
# INFO:root:step: Pingliang -> Guyuan (66.54km)
# INFO:root:step: Guyuan -> Dingxi (154.54km)
# INFO:root:step: Dingxi -> Lanzhou (100.13km)
# INFO:root:step: Lanzhou -> Linxia (64.71km)
# INFO:root:step: Linxia -> Baiyin (135.55km)
# INFO:root:step: Baiyin -> Zhongwei (139.40km)
# INFO:root:step: Zhongwei -> Qingtongxia (82.75km)
# INFO:root:step: Qingtongxia -> Wuzhong (22.37km)
# INFO:root:step: Wuzhong -> Lingwu (16.13km)
# INFO:root:step: Lingwu -> Yinchuan (41.09km)
# INFO:root:step: Yinchuan -> Dawukou (61.15km)
# INFO:root:step: Dawukou -> Shizuishan (41.71km)
# INFO:root:step: Shizuishan -> Hainan (9.84km)
# INFO:root:step: Hainan -> Wuda (24.87km)
# INFO:root:step: Wuda -> Wuhai (16.72km)
# INFO:root:step: Wuhai -> Linhe (148.31km)
# INFO:root:step: Linhe -> Baotou (216.97km)
# INFO:root:step: Baotou -> Erdos (90.87km)
# INFO:root:step: Erdos -> Yulin (169.75km)
# INFO:root:step: Yulin -> Yanan (188.27km)
# INFO:root:step: Yanan -> Hohhot (505.01km)
# INFO:root:step: Hohhot -> Bayannaoer (721.84km)
# INFO:root:step: Bayannaoer -> Wuwei (103.61km)
# INFO:root:step: Wuwei -> Jinchang (78.25km)
# INFO:root:step: Jinchang -> Zhangye (158.10km)
# INFO:root:step: Zhangye -> Jiuquan (190.41km)
# INFO:root:step: Jiuquan -> Jiayuguan (19.60km)
# INFO:root:step: Jiayuguan -> Yumen (48.81km)
# INFO:root:step: Yumen -> Dunhuang (264.02km)
# INFO:root:step: Dunhuang -> Hami (311.36km)
# INFO:root:step: Hami -> Turpan (349.08km)
# INFO:root:step: Turpan -> Ürümqi (158.45km)
# INFO:root:step: Ürümqi -> Miquan (20.88km)
# INFO:root:step: Miquan -> Fukang (26.32km)
# INFO:root:step: Fukang -> Changji (50.72km)
# INFO:root:step: Changji -> Shihezi (107.77km)
# INFO:root:step: Shihezi -> Kuytun (92.19km)
# INFO:root:step: Kuytun -> Usu (55.00km)
# INFO:root:step: Usu -> Karamay (141.42km)
# INFO:root:step: Karamay -> Tacheng (193.23km)
# INFO:root:step: Tacheng -> Bole County (217.10km)
# INFO:root:step: Bole County -> Yining (125.45km)
# INFO:root:step: Yining -> Tumushuke (303.42km)
# INFO:root:step: Tumushuke -> Aksu (33.81km)
# INFO:root:step: Aksu -> Alaer (110.78km)
# INFO:root:step: Alaer -> Hotan (394.32km)
# INFO:root:step: Hotan -> Shache (284.41km)
# INFO:root:step: Shache -> Kashi (161.74km)
# INFO:root:step: Kashi -> Atushi (28.91km)
# INFO:root:step: Atushi -> Korla (873.94km)
# INFO:root:step: Korla -> Altay (696.77km)
# INFO:root:step: Altay -> Golmud (1384.94km)
# INFO:root:step: Golmud -> Lasa (829.31km)
# INFO:root:step: Lasa -> Xigaze (219.18km)
# INFO:root:step: Xigaze -> Xingyi (1650.72km)
# INFO:root:step: Xingyi -> Guilin (543.67km)
# INFO:root:step: Guilin -> Shangzhi (2722.78km)
# INFO:root:step: Shangzhi -> Fujin (386.54km)
# INFO:root:step: Fujin -> Tongjiang (55.63km)
# INFO:root:step: Tongjiang -> Laiyang (1530.61km)

# %% [markdown]
# # SIMULATED ANNEALING

# %%
def fitness(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost



#  mutazione 
def insert_mutation(path):
    path = path.copy()
    i, j = random.sample(range(1, len(path) - 1), 2 ) 

    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path


# mutazione con num_swaps dinamico
def insert_mutation_swap(path, num_swaps):
    path = path.copy()
    
    for _ in range(num_swaps):
        i, j = random.sample(range(1, len(path) - 1), 2)
        
        # Inserisce path[j] in posizione i (controllando l'ordine di i e j)
        if i < j:
            element = path.pop(j)
            path.insert(i + 1, element)
        else:
            element = path.pop(j)
            path.insert(i, element)
    
    return path


# non usata 
def insert_mutation_temp2(path, temperature):
    path = path.copy()
    
    i = random.randint(1, len(path) - 2)
    
    # Calcola una distanza massima tra i e j basata sulla temperatura
    max_distance = int((temperature / 1000) * (len(path) - 2))
    max_distance = max(1, min(max_distance, len(path) - 2))  # Limita max_distance all'intervallo valido

    # j con una distanza casuale fino a max_distance da i
    j = random.randint(max(1, i - max_distance), min(len(path) - 2, i + max_distance))

    # mutazione: 
    if i < j:
        element = path.pop(j)
        path.insert(i + 1, element)
    else:
        element = path.pop(j)
        path.insert(i, element)

    return path




# non usata
def scrambling_mutation(path):
    path = path.copy()
    # subset da mischiare
    i, j = sorted(random.sample(range(1, len(path) - 1), 2))  # Evita punti iniziale e finale

    subset = path[i:j+1]
    random.shuffle(subset)

    path[i:j+1] = subset

    return path

# %% [markdown]
# # SIMULATED ANNEALING

# %%
initial_temp = 1000  
cooling_rate = 0.995
#num_iterations = 700_000  # iterazioni
num_iterations = 1_000_000  # iterazioni # china


#buffer_size = 4                         # russia - italy  
#buffer_size = 5                         # US 
buffer_size = 8                          # china


current_path = list(range(len(CITIES))) + [0]    # Percorso iniziale che parte e torna alla città 0   *** DA SISTEMARE  . inizia con un percorso meglio?????? 


best_path = current_path
current_cost = fitness(current_path)
best_cost = current_cost

temperature = initial_temp
cost_buffer = []

for iteration in tqdm (range(num_iterations) ): 
        
    new_path = insert_mutation(current_path)  ## 
    new_cost = fitness(new_path)

    # Calcola la differenza di costo
    delta_cost = new_cost - current_cost

    # Decide se accettare il nuovo percorso
    if delta_cost < 0 or np.random.random() < np.exp(-delta_cost / temperature):
        current_path = new_path
        current_cost = new_cost

        if current_cost < best_cost:
            best_cost = current_cost
            best_path = current_path

    
    cost_buffer.append(current_cost)
    if len(cost_buffer) > buffer_size:
        cost_buffer.pop(0)

  # Aggiorna la temperatura solo se il trend è in discesa
    if iteration % buffer_size == 0 and len(cost_buffer) == buffer_size:
        avg_cost = np.mean(cost_buffer)
        if avg_cost < current_cost: # Se la media è in discesa ... 
            temperature *= cooling_rate


    if iteration % 100_000 == 0:
        logging.info(f"Iteration {iteration}, Best Cost: {best_cost:.2f} km, Temperature: {temperature:.2f}")

    if temperature < 1e-5:
        break

logging.info(f"Best path found with length {best_cost:.2f} km,  after {iteration} iterations")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:root:Iteration 0, Best Cost: 916713.14 km, Temperature: 1000.00
# INFO:root:Iteration 100000, Best Cost: 188883.63 km, Temperature: 13.69
# INFO:root:Iteration 200000, Best Cost: 153867.57 km, Temperature: 7.50
# INFO:root:Iteration 300000, Best Cost: 138498.27 km, Temperature: 5.26
# INFO:root:Iteration 400000, Best Cost: 129463.02 km, Temperature: 4.15
# INFO:root:Iteration 500000, Best Cost: 121818.75 km, Temperature: 3.59
# INFO:root:Iteration 600000, Best Cost: 116281.82 km, Temperature: 3.00
# INFO:root:Iteration 700000, Best Cost: 113071.03 km, Temperature: 2.47
# INFO:root:Iteration 800000, Best Cost: 110567.36 km, Temperature: 2.16
# INFO:root:Iteration 900000, Best Cost: 104151.15 km, Temperature: 1.96
# INFO:root:Best path found with length 102381.43 km,  after 999999 iterations

# %% [markdown]
# # SIMULATED ANNEALING with swapping mutation

# %%
initial_temp = 1000  
cooling_rate = 0.995
#num_iterations = 700_000  # iterazioni
num_iterations = 1_000_000  # iterazioni # china


#buffer_size = 4                         # russia - italy  
buffer_size = 5                          # US 
buffer_size = 8                          # china


current_path = list(range(len(CITIES))) + [0]

best_path = current_path
current_cost = fitness(current_path)
best_cost = current_cost

temperature = initial_temp
cost_buffer = []


 # num_swaps in base alla temperatura
def calcola_num_swaps(temperature, max_swaps):
    return max(1, int(max_swaps * temperature / initial_temp))



for iteration in tqdm(range(num_iterations)):

    #max_swaps = 4  # russia- italy  ( 4 )
    #max_swaps = 5  # us- china  ( 5 )
    max_swaps = 8   # china   ( 8 )


    num_swaps = calcola_num_swaps(temperature, max_swaps)
    new_path = insert_mutation_swap(current_path, num_swaps)

    new_cost = fitness(new_path)

    delta_cost = new_cost - current_cost

    if delta_cost < 0 or np.random.random() < np.exp(-delta_cost / temperature):
        current_path = new_path
        current_cost = new_cost

        if current_cost < best_cost:
            best_cost = current_cost
            best_path = current_path

    cost_buffer.append(current_cost)
    if len(cost_buffer) > buffer_size:
        cost_buffer.pop(0)

    if iteration % buffer_size == 0 and len(cost_buffer) == buffer_size:
        avg_cost = np.mean(cost_buffer)
        if avg_cost < current_cost:
            temperature *= cooling_rate

    if iteration % 100_000 == 0:
        logging.info(f"Iteration {iteration}, Best Cost: {best_cost:.2f} km, Temperature: {temperature:.2f}")

    if temperature < 1e-5:
        break

logging.info(f"Best path found with length {best_cost:.2f} km, after {iteration} iterations")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:root:Iteration 0, Best Cost: 916713.14 km, Temperature: 1000.00
# INFO:root:Iteration 100000, Best Cost: 187866.35 km, Temperature: 13.83
# INFO:root:Iteration 200000, Best Cost: 158481.94 km, Temperature: 7.43
# INFO:root:Iteration 300000, Best Cost: 145699.60 km, Temperature: 5.42
# INFO:root:Iteration 400000, Best Cost: 135946.92 km, Temperature: 4.22
# INFO:root:Iteration 500000, Best Cost: 125601.10 km, Temperature: 3.49
# INFO:root:Iteration 600000, Best Cost: 120607.32 km, Temperature: 3.06
# INFO:root:Iteration 700000, Best Cost: 115129.31 km, Temperature: 2.66
# INFO:root:Iteration 800000, Best Cost: 111750.68 km, Temperature: 2.42
# INFO:root:Iteration 900000, Best Cost: 108097.55 km, Temperature: 2.20
# INFO:root:Best path found with length 105670.63 km, after 999999 iterations
